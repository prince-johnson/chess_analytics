# %% [markdown]
# # Chess Openings Analytics

# %% [markdown]
# Taking all the games from lichess database

# %%
import pandas as pd
import glob

# %%
# Replace this with your actual path
# path = 'data/*.csv'  
path = 'lichess_db_standard_rated_2016-03/games/*.csv'

# Use glob to get all the CSV file names in the specified path
csv_files = glob.glob(path)
print(csv_files)

# Initialize an empty list to store DataFrames
dataframes = []

# Loop through each file and read it into a DataFrame
for filename in csv_files:
    df = pd.read_csv(filename)  # Read the CSV file
    dataframes.append(df)  # Append the DataFrame to the list

# Concatenate all DataFrames into a single DataFrame
all_games = pd.concat(dataframes, ignore_index=True)
# Out:
# ['lichess_db_standard_rated_2016-03/games\\games_0-99999.csv', 'lichess_db_standard_rated_2016-03/games\\games_100000-199999.csv', 'lichess_db_standard_rated_2016-03/games\\games_1000000-1099999.csv', 'lichess_db_standard_rated_2016-03/games\\games_1100000-1199999.csv', 'lichess_db_standard_rated_2016-03/games\\games_1200000-1299999.csv', 'lichess_db_standard_rated_2016-03/games\\games_1300000-1399999.csv', 'lichess_db_standard_rated_2016-03/games\\games_1400000-1499999.csv', 'lichess_db_standard_rated_2016-03/games\\games_1500000-1599999.csv', 'lichess_db_standard_rated_2016-03/games\\games_1600000-1699999.csv', 'lichess_db_standard_rated_2016-03/games\\games_1700000-1799999.csv', 'lichess_db_standard_rated_2016-03/games\\games_1800000-1899999.csv', 'lichess_db_standard_rated_2016-03/games\\games_1900000-1999999.csv', 'lichess_db_standard_rated_2016-03/games\\games_200000-299999.csv', 'lichess_db_standard_rated_2016-03/games\\games_2000000-2099999.csv', 'lichess_db_standard_rated_2016-03/games\\games_2100000-2199999.csv', 'lichess_db_standard_rated_2016-03/games\\games_2200000-2299999.csv', 'lichess_db_standard_rated_2016-03/games\\games_2300000-2399999.csv', 'lichess_db_standard_rated_2016-03/games\\games_2400000-2499999.csv', 'lichess_db_standard_rated_2016-03/games\\games_2500000-2599999.csv', 'lichess_db_standard_rated_2016-03/games\\games_2600000-2699999.csv', 'lichess_db_standard_rated_2016-03/games\\games_2700000-2799999.csv', 'lichess_db_standard_rated_2016-03/games\\games_2800000-2899999.csv', 'lichess_db_standard_rated_2016-03/games\\games_2900000-2999999.csv', 'lichess_db_standard_rated_2016-03/games\\games_300000-399999.csv', 'lichess_db_standard_rated_2016-03/games\\games_3000000-3099999.csv', 'lichess_db_standard_rated_2016-03/games\\games_3100000-3199999.csv', 'lichess_db_standard_rated_2016-03/games\\games_3200000-3299999.csv', 'lichess_db_standard_rated_2016-03/games\\games_3300000-3399999.csv', 'lichess_db_standard_rated_2016-03/games\\games_3400000-3499999.csv', 'lichess_db_standard_rated_2016-03/games\\games_3500000-3599999.csv', 'lichess_db_standard_rated_2016-03/games\\games_3600000-3699999.csv', 'lichess_db_standard_rated_2016-03/games\\games_3700000-3799999.csv', 'lichess_db_standard_rated_2016-03/games\\games_3800000-3899999.csv', 'lichess_db_standard_rated_2016-03/games\\games_3900000-3999999.csv', 'lichess_db_standard_rated_2016-03/games\\games_400000-499999.csv', 'lichess_db_standard_rated_2016-03/games\\games_4000000-4099999.csv', 'lichess_db_standard_rated_2016-03/games\\games_4100000-4199999.csv', 'lichess_db_standard_rated_2016-03/games\\games_4200000-4299999.csv', 'lichess_db_standard_rated_2016-03/games\\games_4300000-4399999.csv', 'lichess_db_standard_rated_2016-03/games\\games_4400000-4499999.csv', 'lichess_db_standard_rated_2016-03/games\\games_4500000-4599999.csv', 'lichess_db_standard_rated_2016-03/games\\games_4600000-4699999.csv', 'lichess_db_standard_rated_2016-03/games\\games_4700000-4799999.csv', 'lichess_db_standard_rated_2016-03/games\\games_4800000-4899999.csv', 'lichess_db_standard_rated_2016-03/games\\games_4900000-4999999.csv', 'lichess_db_standard_rated_2016-03/games\\games_500000-599999.csv', 'lichess_db_standard_rated_2016-03/games\\games_5000000-5099999.csv', 'lichess_db_standard_rated_2016-03/games\\games_5100000-5199999.csv', 'lichess_db_standard_rated_2016-03/games\\games_5200000-5299999.csv', 'lichess_db_standard_rated_2016-03/games\\games_5300000-5399999.csv', 'lichess_db_standard_rated_2016-03/games\\games_5400000-5499999.csv', 'lichess_db_standard_rated_2016-03/games\\games_5500000-5599999.csv', 'lichess_db_standard_rated_2016-03/games\\games_5600000-5699999.csv', 'lichess_db_standard_rated_2016-03/games\\games_5700000-5799999.csv', 'lichess_db_standard_rated_2016-03/games\\games_5800000-5801233.csv', 'lichess_db_standard_rated_2016-03/games\\games_600000-699999.csv', 'lichess_db_standard_rated_2016-03/games\\games_700000-799999.csv', 'lichess_db_standard_rated_2016 ...

# %% [markdown]
# Inspecting the data

# %%
print(all_games.head())  # View the first few rows
all_games.info()  # Overview of column types and non-null counts
all_games.describe()  # Summary statistics
# Out:
#                                                Event  \
# 0  Rated Blitz tournament https://lichess.org/tou...
# 1                                   Rated Blitz game
# 2  Rated Bullet tournament https://lichess.org/to...
# 3  Rated Blitz tournament https://lichess.org/tou...
# 4  Rated Classical tournament https://lichess.org...
#
#                            Site              White           Black Result  \
# 0  https://lichess.org/BX9cNQC4  cacho_mascachotta    Urbi-Et-Orbi    0-1
# 1  https://lichess.org/PwE2cWn3        Mescalero25          fialho    1-0
# 2  https://lichess.org/sI2AWiHX         theosis101      sebafreire    1-0
# 3  https://lichess.org/qAS73D1T          BrettDale  Viriskensoshir    0-1
# 4  https://lichess.org/GbvwpLxO              borgs       IntiTupac    0-1
#
#    WhiteElo  BlackElo WhiteRatingDiff BlackRatingDiff  ECO  \
# 0      1563      1409             -17             +20    ?
# 1      2044      2124             +17             -13  C00
# 2      1677      1736             +14             -14  A43
# 3      1905      1949             -10             +10  B72
# 4      1726      1702             -12             +14  A13
#
#                                       Opening TimeControl   Termination
# 0                                           ?       180+0        Normal
# 1        French Defense: King's Indian Attack       300+0        Normal
# 2                          Old Benoni Defense        60+0  Time forfeit
# 3  Sicilian Defense: Dragon, Classical Attack       180+0        Normal
# 4       English Opening: Agincourt Defense #3       600+0  Time forfeit
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5801175 entries, 0 to 5801174
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Event            object
#  1   Site             object
#  2   White            object
#  3   Black            object
#  4   Result           object
#  5   WhiteElo         int64
#  6   BlackElo         int64
#  7   WhiteRatingDiff  object
#  8   BlackRatingDiff  object
#  9   ECO              object
#  10  Opening          object
#  11  TimeControl      object
#  12  Termination      object
# dtypes: int64(2), object(11)
# memory usage: 575.4+ MB
#            WhiteElo      BlackElo
# count  5.801175e+06  5.801175e+06
# mean   1.736396e+03  1.734673e+03
# std    2.764165e+02  2.777737e+02
# min    7.340000e+02  7.450000e+02
# 25%    1.546000e+03  1.543000e+03
# 50%    1.734000e+03  1.732000e+03
# 75%    1.921000e+03  1.920000e+03
# max    3.103000e+03  3.103000e+03

# %% [markdown]
# Check for missing values

# %%
all_games.isnull().sum()
# Out:
# Event              0
# Site               0
# White              0
# Black              0
# Result             0
# WhiteElo           0
# BlackElo           0
# WhiteRatingDiff    0
# BlackRatingDiff    0
# ECO                0
# Opening            0
# TimeControl        0
# Termination        0
# dtype: int64

# %% [markdown]
# Distribution of Elo Ratings

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(all_games['WhiteElo'], color='blue', label='White Elo', kde=True)
sns.histplot(all_games['BlackElo'], color='red', label='Black Elo', kde=True)
plt.legend()
plt.title('Distribution of Elo Ratings')
plt.show()

# %% [markdown]
# Opening Analysis
# Analyze which openings are more frequent and how they relate to outcomes.

# %%
opening_counts = all_games['Opening'].value_counts()
print(opening_counts.head(10))  # Top 10 most frequent openings

sns.countplot(y='Opening', data=all_games, order=opening_counts.index[:10])
plt.title('Top 10 Most Played Openings')
plt.show()
# Out:
# Opening
# Van't Kruijs Opening                             123946
# Scandinavian Defense: Mieses-Kotroc Variation    108984
# Modern Defense                                   107968
# Horwitz Defense                                   90261
# Sicilian Defense                                  81495
# Scandinavian Defense                              78369
# French Defense: Knight Variation                  76671
# Caro-Kann Defense                                 72367
# Sicilian Defense: Bowdler Attack                  67245
# Owen Defense                                      65053
# Name: count, dtype: int64

# %% [markdown]
# Specific openings perform with different Elo levels

# %%
top_openings = all_games['Opening'].value_counts().nlargest(10).index
filtered_data = all_games[all_games['Opening'].isin(top_openings)]

plt.figure(figsize=(12, 8))
sns.boxplot(x='Result', y='WhiteElo', data=filtered_data, hue='Opening')
plt.title('White Elo vs Result by Top Openings')
plt.show()

# %% [markdown]
# outcome analysis

# %%
result_counts = all_games['Result'].value_counts()
sns.countplot(x='Result', data=all_games)
plt.title('Game Result Distribution')
plt.show()

# %% [markdown]
# Compare the Elo difference between White and Black for different results:

# %%
all_games['elo_diff'] = all_games['WhiteElo'] - all_games['BlackElo']

sns.boxplot(x='Result', y='elo_diff', data=all_games)
plt.title('Elo Difference vs Result')
plt.show()

# %% [markdown]
# Correlation Analysis

# %%
# Create a new numeric column for results
def encode_result(result):
    if result == '1-0':
        return 1  # White wins
    elif result == '0-1':
        return 0  # Black wins
    else:
        return 0.5  # Draw

# Apply the function to create a new column
all_games['ResultNumeric'] = all_games['Result'].apply(encode_result)

# Now calculate the correlation matrix including the new numeric result column
corr_matrix = all_games[['WhiteElo', 'BlackElo', 'elo_diff', 'ResultNumeric']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix with Numeric Results')
plt.show()

all_games.drop(['ResultNumeric'], axis=1, inplace=True)

# %% [markdown]
# Elo Distribution

# %% [markdown]
#  Win Rate Analysis

# %%
win_rates = all_games.groupby('WhiteElo')['Result'].apply(lambda x: (x == '1-0').mean())
plt.figure(figsize=(12, 6))
win_rates.plot()
plt.title('Win Rate of White Players by Elo Rating')
plt.xlabel('White Elo Rating')
plt.ylabel('Win Rate')
plt.grid()
plt.show()

# %% [markdown]
# Opening Performance Analysis

# %% [markdown]
# ## Feature Engineering

# %%
all_games.columns

# lets take only the classical games for this analysis 
# Display all unique values in the Event column
unique_events = all_games['Event'].unique()
unique_termination = all_games['Termination'].unique()
print(unique_events)
print(unique_termination)
# Out:
# ['Rated Blitz tournament https://lichess.org/tournament/XLiNy5KR'
#  'Rated Blitz game'
#  'Rated Bullet tournament https://lichess.org/tournament/swlsEYuM' ...
#  'Rated Bullet tournament https://lichess.org/tournament/BXYcg0GG'
#  'Rated Blitz tournament https://lichess.org/tournament/KAAykwdN'
#  'Rated Bullet tournament https://lichess.org/tournament/WnhID9rM']
# ['Normal' 'Time forfeit' 'Abandoned' 'Rules infraction' 'Unterminated']

# %%
# from that we  only need classical 
# Filter for classical games (assuming 'Classical' is part of the Event name)
classical_games = all_games[all_games['Event'].str.contains('Classical', case=False)]

# Remove games where Termination is 'Abandoned' or 'Rules infraction'
rated_classical_games = classical_games[~classical_games['Termination'].isin(['Abandoned', 'Rules infraction'])]

# Verify the result by printing the first few rows
print(rated_classical_games.head())
# Out:
#                                                 Event  \
# 4   Rated Classical tournament https://lichess.org...
# 10                               Rated Classical game
# 12  Rated Classical tournament https://lichess.org...
# 13                               Rated Classical game
# 14  Rated Classical tournament https://lichess.org...
#
#                             Site         White          Black Result  \
# 4   https://lichess.org/GbvwpLxO         borgs      IntiTupac    0-1
# 10  https://lichess.org/yvnA3VUA        tacaia        marossi    0-1
# 12  https://lichess.org/55wUvBYG  FernandoWolf          Shir0    1-0
# 13  https://lichess.org/OnHyLf9F  bahrameshghi        cordoba    1-0
# 14  https://lichess.org/CfPynoUd  BESERKING123  Ricardo-Lopes    1-0
#
#     WhiteElo  BlackElo WhiteRatingDiff BlackRatingDiff  ECO  \
# 4       1726      1702             -12             +14  A13
# 10      1274      1360              -8              +9  A41
# 12      1641      1533              +9              -8  A00
# 13      1548      1737             +18             -17  B44
# 14      1852      1851             +17             -11  A42
#
#                                    Opening TimeControl   Termination  elo_diff
# 4    English Opening: Agincourt Defense #3       600+0  Time forfeit        24
# 10                            Queen's Pawn       600+3        Normal       -86
# 12  Van Geet Opening: Reversed Nimzowitsch       600+0        Normal       108
# 13     Sicilian Defense: Paulsen Variation       900+0        Normal      -189
# 14      Modern Defense: Averbakh Variation       600+0  Time forfeit         1

# %% [markdown]
# Taking Only the serious games

# %%
# Count the number of games for each player (both White and Black)
white_game_counts = rated_classical_games['White'].value_counts()
black_game_counts = rated_classical_games['Black'].value_counts()

# Combine the counts to get total games played by each player
total_game_counts = white_game_counts.add(black_game_counts, fill_value=0)

# The cutoff_value of 118 means that 90% of players 
# have played fewer than 118 games, 
# while the top 10% of players have played 118 games or more. 
# This is the 90th percentile of the total number of games played by each player.


# Calculate the 90th percentile of total games played
cutoff_value = total_game_counts.quantile(0.9) # 118

# Filter for games where both players have played more than the cutoff
serious_games = rated_classical_games[(
    rated_classical_games['White'].isin(total_game_counts[total_game_counts > cutoff_value].index) &
    rated_classical_games['Black'].isin(total_game_counts[total_game_counts > cutoff_value].index)
)]

# Print the number of serious games
print(serious_games)

# Plot the distribution of total game counts
plt.figure(figsize=(10, 6))
sns.histplot(serious_games, bins=50, kde=True)
plt.title('Distribution of Total Games Played by Players')
plt.xlabel('Total Games Played')
plt.ylabel('Number of Players')
plt.show()
# Out:
#                                                      Event  \
# 4        Rated Classical tournament https://lichess.org...
# 10                                    Rated Classical game
# 12       Rated Classical tournament https://lichess.org...
# 27       Rated Classical tournament https://lichess.org...
# 39                                    Rated Classical game
# ...                                                    ...
# 5801139                               Rated Classical game
# 5801141                               Rated Classical game
# 5801142                               Rated Classical game
# 5801163                               Rated Classical game
# 5801169                               Rated Classical game
#
#                                  Site            White        Black Result  \
# 4        https://lichess.org/GbvwpLxO            borgs    IntiTupac    0-1
# 10       https://lichess.org/yvnA3VUA           tacaia      marossi    0-1
# 12       https://lichess.org/55wUvBYG     FernandoWolf        Shir0    1-0
# 27       https://lichess.org/4BhapBM7            CZERW     FFF_Nico    0-1
# 39       https://lichess.org/aee9yMYW      hatzopoulos    monaco712    0-1
# ...                               ...              ...          ...    ...
# 5801139  https://lichess.org/fxeaNR2J  Delfoscabernard       game13    0-1
# 5801141  https://lichess.org/d2qeXG5h           Zetton     dralihan    1-0
# 5801142  https://lichess.org/o3YnNTBS    lyubenrumenov      greco27    1-0
# 5801163  https://lichess.org/LyG5dB6Y    achnaratasaba       lp2306    0-1
# 5801169  https://lichess.org/ZSYFAkKc           orljan  shaarslanov    1-0
#
#          WhiteElo  BlackElo WhiteRatingDiff BlackRatingDiff  ECO  \
# 4            1726      1702             -12             +14  A13
# 10           1274      1360              -8              +9  A41
# 12           1641      1533              +9              -8  A00
# 27           1437      1220             -22             +34  A00
# 39           1509      1587              -8              +9  C20
# ...           ...       ...             ...             ...  ...
# 5801139      1714      1671             -11             +13  C20
# 5801141      1690      1692             +77             -10  A40
# 5801142      1515      1459             +10              -8  C34
# 5801163      1265      1624              -3              +4  D02
# 5801169      2037      1892              +8              -7  B06
#
#                                               Opening TimeControl  \
# 4               English Opening: Agincourt Defense #3       600+0
# 10                                       Queen's Pawn       600+3
# 12             Van Geet Opening: Reversed Nimzowitsch       600+0
# 27                                      Kadas Opening       600+0
# 39                  King's Pawn Game: Napoleon Attack       600+0
# ...                                               ...         ...
# 5801139                              King's Pawn Game       900+0
# 5801141         Englund Gambit Complex: Soller Gambit       300+5
# 5801142  King's Gambit Accepted, King's Knight Gambit       600+0
# 5801163                 Queen's Pawn Game: Anti-Torre       600+5
# 5801169            Modern Defense: Three Pawns Attack       600+0
#
#           Termination  elo_diff
# 4        Time forfeit        24
# 10             Normal       -86
# 12             Normal       108
# 27             Normal       217
# 39             Normal       -78
# ...               ...       ...
# 5801139        Normal        43
# 5801141        Normal        -2
# 5801142  Time forfeit        56
# 5801163        Normal      -359
# 5801169        Normal       145
#
# [475419 rows x 14 columns]

# %%
# Print the cutoff value and inspect serious games
print(f"90th percentile cutoff for total games: {cutoff_value}")
print(serious_games.head())

# If needed, adjust to a different percentile
cutoff_value_95 = total_game_counts.quantile(0.95)
print(f"95th percentile cutoff: {cutoff_value_95}")

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(serious_games['WhiteElo'], color='blue', label='White Elo', kde=True)
sns.histplot(serious_games['BlackElo'], color='red', label='Black Elo', kde=True)
plt.legend()
plt.title('Distribution of Elo Ratings')
plt.show()
# Out:
# 90th percentile cutoff for total games: 118.0
#                                                 Event  \
# 4   Rated Classical tournament https://lichess.org...
# 10                               Rated Classical game
# 12  Rated Classical tournament https://lichess.org...
# 27  Rated Classical tournament https://lichess.org...
# 39                               Rated Classical game
#
#                             Site         White      Black Result  WhiteElo  \
# 4   https://lichess.org/GbvwpLxO         borgs  IntiTupac    0-1      1726
# 10  https://lichess.org/yvnA3VUA        tacaia    marossi    0-1      1274
# 12  https://lichess.org/55wUvBYG  FernandoWolf      Shir0    1-0      1641
# 27  https://lichess.org/4BhapBM7         CZERW   FFF_Nico    0-1      1437
# 39  https://lichess.org/aee9yMYW   hatzopoulos  monaco712    0-1      1509
#
#     BlackElo WhiteRatingDiff BlackRatingDiff  ECO  \
# 4       1702             -12             +14  A13
# 10      1360              -8              +9  A41
# 12      1533              +9              -8  A00
# 27      1220             -22             +34  A00
# 39      1587              -8              +9  C20
#
#                                    Opening TimeControl   Termination  elo_diff
# 4    English Opening: Agincourt Defense #3       600+0  Time forfeit        24
# 10                            Queen's Pawn       600+3        Normal       -86
# 12  Van Geet Opening: Reversed Nimzowitsch       600+0        Normal       108
# 27                           Kadas Opening       600+0        Normal       217
# 39       King's Pawn Game: Napoleon Attack       600+0        Normal       -78
# 95th percentile cutoff: 185.0

# %%
# drop all the columns except white elo black elo  opening and result

filtered_games = serious_games[['WhiteElo', 'BlackElo', 'Opening', 'Result']]

# write to csv

filtered_games.to_csv('data/serious_games.csv', index=False)

# %% [markdown]
# ## Random Forest Classifier Training and Testing

# %%
# import joblib
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
serious_games = pd.read_csv('data/serious_games.csv')

le_opening = LabelEncoder()

serious_games['Opening'] = le_opening.fit_transform(serious_games['Opening'])

encoded = pd.get_dummies(serious_games[[ 'WhiteElo', 'BlackElo', 'Result', 'Opening' ]], columns = ['Result'])

# %%
encoded
# Out:
#         WhiteElo  BlackElo  Opening  Result_0-1  Result_1-0  Result_1/2-1/2
# 0           1726      1702      365        True       False           False
# 1           1274      1360     1541        True       False           False
# 2           1641      1533     2227       False        True           False
# 3           1437      1220      830        True       False           False
# 4           1509      1587     1053        True       False           False
# ...          ...       ...      ...         ...         ...             ...
# 475414      1714      1671     1031        True       False           False
# 475415      1690      1692      465       False        True           False
# 475416      1515      1459      873       False        True           False
# 475417      1265      1624     1546        True       False           False
# 475418      2037      1892     1120       False        True           False
#
# [475419 rows x 6 columns]

# %%
opening_encodings = dict(zip(le_opening.classes_, le_opening.transform(le_opening.classes_)))

# %%
opening_encodings
# Out:
# {'?': np.int64(0),
#  'Alekhine Defense': np.int64(1),
#  'Alekhine Defense #2': np.int64(2),
#  'Alekhine Defense #3': np.int64(3),
#  'Alekhine Defense: Balogh Variation': np.int64(4),
#  'Alekhine Defense: Brooklyn Variation': np.int64(5),
#  'Alekhine Defense: Brooklyn Variation, Everglades Variation': np.int64(6),
#  'Alekhine Defense: Exchange Variation': np.int64(7),
#  'Alekhine Defense: Four Pawns Attack': np.int64(8),
#  'Alekhine Defense: Four Pawns Attack, 6...Nc6': np.int64(9),
#  'Alekhine Defense: Four Pawns Attack, Cambridge Gambit': np.int64(10),
#  'Alekhine Defense: Four Pawns Attack, Fianchetto Variation': np.int64(11),
#  'Alekhine Defense: Four Pawns Attack, Main Line': np.int64(12),
#  'Alekhine Defense: Four Pawns Attack, Tartakower Variation': np.int64(13),
#  'Alekhine Defense: Four Pawns Attack, Trifunovic Variation': np.int64(14),
#  'Alekhine Defense: Hunt Variation': np.int64(15),
#  'Alekhine Defense: Hunt Variation, Lasker Simul Gambit': np.int64(16),
#  'Alekhine Defense: John Tracy Gambit': np.int64(17),
#  'Alekhine Defense: Kmoch Variation': np.int64(18),
#  'Alekhine Defense: Krejcik Variation': np.int64(19),
#  'Alekhine Defense: Krejcik Variation, Krejcik Gambit': np.int64(20),
#  'Alekhine Defense: Maroczy Variation': np.int64(21),
#  'Alekhine Defense: Modern Variation': np.int64(22),
#  'Alekhine Defense: Modern Variation, Alburt Variation': np.int64(23),
#  'Alekhine Defense: Modern Variation, Alekhine Gambit': np.int64(24),
#  'Alekhine Defense: Modern Variation, Alekhine Variation': np.int64(25),
#  'Alekhine Defense: Modern Variation, Larsen Variation': np.int64(26),
#  'Alekhine Defense: Modern Variation, Larsen-Haakert Variation': np.int64(27),
#  'Alekhine Defense: Modern Variation, Main Line': np.int64(28),
#  'Alekhine Defense: Modern Variation, Panov Variation': np.int64(29),
#  'Alekhine Defense: Modern Variation, Schmid Variation': np.int64(30),
#  'Alekhine Defense: Mokele Mbembe': np.int64(31),
#  'Alekhine Defense: Mokele Mbembe, Modern Line': np.int64(32),
#  'Alekhine Defense: Mokele Mbembe, Vavra Defense': np.int64(33),
#  'Alekhine Defense: Normal Variation': np.int64(34),
#  "Alekhine Defense: O'Sullivan Gambit": np.int64(35),
#  'Alekhine Defense: Saemisch Attack': np.int64(36),
#  'Alekhine Defense: Scandinavian Variation': np.int64(37),
#  'Alekhine Defense: Scandinavian Variation, Geschev Gambit': np.int64(38),
#  'Alekhine Defense: Scandinavian Variation, Myers Gambit': np.int64(39),
#  'Alekhine Defense: Spielmann Gambit': np.int64(40),
#  'Alekhine Defense: Steiner Variation': np.int64(41),
#  'Alekhine Defense: The Squirrel': np.int64(42),
#  'Alekhine Defense: Two Pawn Attack': np.int64(43),
#  'Alekhine Defense: Two Pawn Attack, Lasker Variation': np.int64(44),
#  'Alekhine Defense: Welling Variation': np.int64(45),
#  'Amar Opening': np.int64(46),
#  'Amazon Attack': np.int64(47),
#  'Amazon Attack: Siberian Attack': np.int64(48),
#  'Anderssen Opening': np.int64(49),
#  'Australian Defense': np.int64(50),
#  'Barnes Defense': np.int64(51),
#  "Barnes Opening: Fool's Mate": np.int64(52),
#  'Barnes Opening: Gedult Gambit': np.int64(53),
#  'Barnes Opening: Walkerling': np.int64(54),
#  'Benko Gambit': np.int64(55),
#  'Benko Gambit Accepted': np.int64(56),
#  'Benko Gambit Accepted, Central Storming Variation': np.int64(57),
#  'Benko Gambit Accepted, Dlugy Variation': np.int64(58),
#  'Benko Gambit Accepted, Fianchetto Variation': np.int64(59),
#  'Benko Gambit Accepted, Fully Accepted Variation': np.int64(60),
#  'Benko Gambit Accepted, Modern Variation': np.int64(61),
#  'Benko Gambit Accepted, Pawn Return Variation': np.int64(62),
#  'Benko Gambit Accepted, Yugoslav, without 7...Bxf1': np.int64(63),
#  'Benko Gambit Declined, Bishop Attack': np.int64(64),
#  'Benko Gambit Declined, Hjoerring Countergambit': np.int64(65),
#  'Benko Gambit Declined, Main Line': np.int64(66),
#  'Benko Gambit Declined, Quiet Line': np.int64(67),
#  'Benko Gambit: Nescafe Frappe Attack': np.int64(68),
#  'Benko Gambit: Zaitsev System': np.int64(69),
#  'Benko Gambit: Zaitsev Variation, Nescafe Frappe Attack': np.int64(70),
#  'Benoni Defense': np.int64(71),
#  'Benoni Defense: Benoni Gambit Accepted': np.int64(72),
#  'Benoni Defense: Benoni Gambit, Schlenker Defense': np.int64(73),
#  'Benoni Defense: Benoni-Indian Defense': np.int64(74),
#  'Benoni Defense: Benoni-Indian Defense, Kingside Move Order': np.int64(75),
#  'Benoni Defense: Classical Variation': np.int64(76),
#  'Benoni Defense: Classical Variation, Averbakh-Grivas Attack': np.int64(77),
#  'Benoni Defense: Classical Variation, Czerniak Defense': np.int64(78),
#  'Benoni Defense: Classical Variation, Main Line': np.int64(79),
#  'Benoni Defense: Classical Variation, New York Variation': np.int64(80),
#  'Benoni Defense: Classical Variation, Traditional Variation': np.int64(81),
#  'Benoni Defense: Classical, without 9.O-O': np.int64(82),
#  'Benoni Defense: Cormorant Gambit': np.int64(83),
#  'Benoni Defense: Czech Benoni Defense': np.int64(84),
#  'Benoni Defense: Fianchetto Variation': np.int64(85),
#  'Benoni Defense: Four Pawns Attack': np.int64(86),
#  'Benoni Defense: Four Pawns Attack, Main Line': np.int64(87),
#  'Benoni Defense: Franco-Sicilian Hybrid': np.int64(88),
#  'Benoni Defense: Hawk Variation': np.int64(89),
#  'Benoni Defense: Hromadka System': np.int64(90),
#  "Benoni Defense: King's Indian System": np.int64(91),
#  "Benoni Defense: King's Pawn Line": np.int64(92),
#  "Benoni Defense: Knight's Tour Variation": np.int64(93),
#  'Benoni Defense: Mikenas Variation': np.int64(94),
#  'Benoni Defense: Modern Variation': np.int64(95),
#  'Benoni Defense: Modern Variation, Snake Variation': np.int64(96),
#  'Benoni Defense: Old Benoni': np.int64(97),
#  'Benoni Defense: Old Benoni, Schmid Variation': np.int64(98),
#  'Benoni Defense: Pawn Storm Variation': np.int64(99),
#  'Benoni Defense: Snail Variation': np.int64(100),
#  'Benoni Defense: Uhlmann Variation': np.int64(101),
#  'Benoni Defense: Weenink Variation': np.int64(102),
#  'Benoni Defense: Woozle': np.int64(103),
#  'Bird Opening': np.int64(104),
#  'Bird Opening: Dutch Variation': np.int64(105),
#  'Bird Opening: Dutch Variation, Batavo Gambit': np.int64(106),
#  'Bird Opening: Dutch Variation, Dudweiler Gambit': np.int64(107),
#  "Bird Opening: From's Gambit": np.int64(108),
#  "Bird Opening: From's Gambit, Bahr Gambit": np.int64(109),
#  "Bird Opening: From's Gambit, Lasker Variation": np.int64(110),
#  'Bird Opening: Hobbs Gambit': np.int64(111),
#  'Bird Opening: Horsefly Defense': np.int64(112),
#  'Bird Opening: Lasker Gambit': np.int64(113),
#  'Bird Opening: Lasker Variation': np.int64(114),
#  'Bird Opening: Mujannah': np.int64(115),
#  'Bird Opening: Myers Defense': np.int64(116),
#  'Bird Opening: Platz Gambit': np.int64(117),
#  'Bird Opening: Schlechter Gambit': np.int64(118),
#  'Bird Opening: Sturm Gambit': np.int64(119),
#  'Bird Opening: Wagner-Zwitersch Gambit': np.int64(120),
#  'Bird Opening: Williams Gambit': np.int64(121),
#  "Bishop's Opening": np.int64(122),
#  "Bishop's Opening: Anderssen Gambit": np.int64(123),
#  "Bishop's Opening: Berlin Defense": np.int64(124),
#  "Bishop's Opening: Berlin Defense, Greco Gambit": np.int64(125),
#  "Bishop's Opening: Boden-Kieseritzky Gambit": np.int64(126),
#  "Bishop's Opening: Boi Variation": np.int64(127),
#  "Bishop's Opening: Calabrese Countergambit": np.int64(128),
#  "Bishop's Opening: Calabrese Countergambit, Jaenisch Variation": np.int64(129),
#  "Bishop's Opening: Khan Gambit": np.int64(130),
#  "Bishop's Opening: Kitchener Folly": np.int64(131),
#  "Bishop's Opening: Lewis Countergambit #2": np.int64(132),
#  "Bishop's Opening: Lewis Gambit": np.int64(133),
#  "Bishop's Opening: Lisitsyn Variation": np.int64(134),
#  "Bishop's Opening: Lopez Variation": np.int64(135),
#  "Bishop's Opening: McDonnell Gambit": np.int64(136),
#  "Bishop's Opening: McDonnell Gambit, La Bourdonnais-Denker Gambit": np.int64(137),
#  "Bishop's Opening: Philidor Counterattack": np.int64(138),
#  "Bishop's Opening: Philidor Variation": np.int64(139),
#  "Bishop's Opening: Ponziani Gambit": np.int64(140),
#  "Bishop's Opening: Stein Gambit": np.int64(141),
#  "Bishop's Opening: Urusov Gambit": np.int64(142),
#  "Bishop's Opening: Urusov Gambit, Keidansky Gambit": np.int64(143),
#  "Bishop's Opening: Vienna Hybrid": np.int64(144),
#  "Bishop's Opening: Vienna Hybrid, Hromadka Variation": np.int64(145),
#  "Bishop's Opening: Vienna Hybrid, Spielmann Attack": np.int64(146),
#  "Bishop's Opening: Warsaw Gambit": np.int64(147),
#  'Blackmar-Diemer Gambit': np.int64(148),
#  'Blackmar-Diemer Gambit #2': np.int64(149),
#  'Blackmar-Diemer Gambit Declined, Brombacher Countergambit': np.int64(150),
#  'Blackmar-Diemer Gambit Declined, Elbert Countergambit': np.int64(151),
#  'Blackmar-Diemer Gambit Declined, Grosshans Defense': np.int64(152),
#  'Blackmar-Diemer Gambit Declined, Lamb Defense': np.int64(153),
#  'Blackmar-Diemer Gambit Declined, Langeheinecke Defense': np.int64(154),
#  "Blackmar-Diemer Gambit Declined, O'Kelly Defense": np.int64(155),
#  'Blackmar-Diemer Gambit Declined, Weinsbach Declination': np.int64(156),
#  'Blackmar-Diemer Gambit: Diemer-Rosenberg Attack': np.int64(157),
#  'Blackmar-Diemer Gambit: Euwe Defense': np.int64(158),
#  'Blackmar-Diemer Gambit: Fritz Attack': np.int64(159),
#  'Blackmar-Diemer Gambit: Gedult Gambit': np.int64(160),
#  'Blackmar-Diemer Gambit: Kaulich Defense': np.int64(161),
#  'Blackmar-Diemer Gambit: Lemberger Countergambit, Diemer Attack': np.int64(162),
#  'Blackmar-Diemer Gambit: Lemberger Countergambit, Endgame Variation': np.int64(163),
#  'Blackmar-Diemer Gambit: Lemberger Countergambit, Rassmussen Attack': np.int64(164),
#  'Blackmar-Diemer Gambit: Lemberger Countergambit, Simple Variation': np.int64(165),
#  'Blackmar-Diemer Gambit: Netherlands Variation': np.int64(166),
#  'Blackmar-Diemer Gambit: Pietrowsky Defense': np.int64(167),
#  'Blackmar-Diemer Gambit: Rasa-Studier Gambit': np.int64(168),
#  'Blackmar-Diemer Gambit: Ryder Gambit': np.int64(169),
#  'Blackmar-Diemer Gambit: Schlutter Defense': np.int64(170),
#  'Blackmar-Diemer Gambit: Tartakower Variation': np.int64(171),
#  'Blackmar-Diemer Gambit: Teichmann Variation': np.int64(172),
#  'Blackmar-Diemer Gambit: Vienna Variation': np.int64(173),
#  'Blackmar-Diemer Gambit: Zeller Defense': np.int64(174),
#  'Blackmar-Diemer Gambit: Zeller Defense, Soller Attack': np.int64(175),
#  'Blackmar-Diemer Gambit: Ziegler Defense': np.int64(176),
#  'Blackmar-Diemer Gambit: von Popiel Gambit': np.int64(177),
#  'Blackmar-Diemer, Lemberger Countergambit': np.int64(178),
#  'Blumenfeld Countergambit': np.int64(179),
#  'Blumenfeld Countergambit #2': np.int64(180),
#  'Bogo-Indian Defense: Exchange Variation': np.int64(181),
#  'Bogo-Indian Defense: Gruenfeld Variation': np.int64(182),
#  'Bogo-Indian Defense: Haiti Variation': np.int64(183),
#  'Bogo-Indian Defense: Nimzowitsch Variation': np.int64(184),
#  'Bogo-Indian Defense: Retreat Variation': np.int64(185),
#  'Bogo-Indian Defense: Vitolins Variation': np.int64(186),
#  'Bogo-Indian Defense: Wade-Smyslov Variation': np.int64(187),
#  'Borg Defense': np.int64(188),
#  'Borg Defense: Borg Gambit': np.int64(189),
#  'Borg Defense: Troon Gambit': np.int64(190),
#  'Borg Opening: Zilbermints Gambit': np.int64(191),
#  'Bronstein Gambit': np.int64(192),
#  'Budapest Defense': np.int64(193),
#  'Budapest Defense: Adler Variation': np.int64(194),
#  'Budapest Defense: Alekhine Variation': np.int64(195),
#  'Budapest Defense: Alekhine Variation, Abonyi Variation': np.int64(196),
#  'Budapest Defense: Alekhine Variation, Tartakower Defense': np.int64(197),
#  'Budapest Defense: Fajarowicz Defense, Bonsdorf Variation': np.int64(198),
#  'Budapest Defense: Fajarowicz Variation': np.int64(199),
#  'Budapest Defense: Fajarowicz-Steiner Variation': np.int64(200),
#  'Budapest Defense: Rubinstein Variation': np.int64(201),
#  'Canard Opening': np.int64(202),
#  'Caro-Kann Defense': np.int64(203),
#  'Caro-Kann Defense #2': np.int64(204),
#  'Caro-Kann Defense: Accelerated Panov Attack': np.int64(205),
#  'Caro-Kann Defense: Accelerated Panov Attack #2': np.int64(206),
#  'Caro-Kann Defense: Accelerated Panov Attack, Modern Variation': np.int64(207),
#  'Caro-Kann Defense: Accelerated Panov Attack, Open Variation': np.int64(208),
#  'Caro-Kann Defense: Advance Variation': np.int64(209),
#  'Caro-Kann Defense: Advance Variation, Bayonet Attack': np.int64(210),
#  'Caro-Kann Defense: Advance Variation, Botvinnik-Carls Defense': np.int64(211),
#  'Caro-Kann Defense: Advance Variation, Bronstein Variation': np.int64(212),
#  'Caro-Kann Defense: Advance Variation, Prins Attack': np.int64(213),
#  'Caro-Kann Defense: Advance Variation, Short Variation': np.int64(214),
#  'Caro-Kann Defense: Advance Variation, Tal Variation': np.int64(215),
#  'Caro-Kann Defense: Advance Variation, Van der Wiel Attack': np.int64(216),
#  'Caro-Kann Defense: Advance Variation, Van der Wiel Attack, Dreyev Defense': np.int64(217),
#  'Caro-Kann Defense: Advance, Short Variation': np.int64(218),
#  'Caro-Kann Defense: Alekhine Gambit': np.int64(219),
#  'Caro-Kann Defense: Breyer Variation': np.int64(220),
#  'Caro-Kann Defense: Bronstein-Larsen Variation': np.int64(221),
#  'Caro-Kann Defense: Classical Variation': np.int64(222),
#  'Caro-Kann Defense: Classical Variation, Lobron System': np.int64(223),
#  'Caro-Kann Defense: Classical Variation, Main Line': np.int64(224),
#  'Caro-Kann Defense: Classical Variation, Maroczy Attack': np.int64(225),
#  'Caro-Kann Defense: Classical Variation, Seirawan Variation': np.int64(226),
#  'Caro-Kann Defense: Classical, 7...Nd7': np.int64(227),
#  'Caro-Kann Defense: Classical, Spassky Variation': np.int64(228),
#  'Caro-Kann Defense: De Bruycker Defense': np.int64(229),
#  'Caro-Kann Defense: Edinburgh Variation': np.int64(230),
#  'Caro-Kann Defense: Euwe Attack': np.int64(231),
#  'Caro-Kann Defense: Exchange Variation': np.int64(232),
#  'Caro-Kann Defense: Exchange Variation, Rubinstein Variation': np.int64(233),
#  'Caro-Kann Defense: Finnish Variation': np.int64(234),
#  'Caro-Kann Defense: Forgacs Variation': np.int64(235),
#  'Caro-Kann Defense: Goldman Variation': np.int64(236),
#  'Caro-Kann Defense: Gurgenidze Counterattack': np.int64(237),
#  'Caro-Kann Defense: Gurgenidze System': np.int64(238),
#  'Caro-Kann Defense: Hillbilly Attack': np.int64(239),
#  'Caro-Kann Defense: Hillbilly Attack, Schaeffer Gambit': np.int64(240),
#  'Caro-Kann Defense: Karpov Variation': np.int64(241),
#  'Caro-Kann Defense: Karpov Variation, Modern Variation': np.int64(242),
#  'Caro-Kann Defense: Karpov Variation, Modern Variation, Kasparov Attack': np.int64(243),
#  'Caro-Kann Defense: Karpov Variation, Tiviakov-Fischer Attack': np.int64(244),
#  'Caro-Kann Defense: Labahn Attack': np.int64(245),
#  'Caro-Kann Defense: Labahn Attack, Double Gambit': np.int64(246),
#  'Caro-Kann Defense: Main Line': np.int64(247),
#  'Caro-Kann Defense: Maroczy Variation': np.int64(248),
#  'Caro-Kann Defense: Masi Variation': np.int64(249),
#  'Caro-Kann Defense: Massachusetts Defense': np.int64(250),
#  'Caro-Kann Defense: Modern Variation': np.int64(251),
#  'Caro-Kann Defense: Panov Attack': np.int64(252),
#  'Caro-Kann Defense: Panov Attack #2': np.int64(253),
#  'Caro-Kann Defense: Panov Attack, Fianchetto Defense': np.int64(254),
#  'Caro-Kann Defense: Panov Attack, Gunderam Attack': np.int64(255),
#  'Caro-Kann Defense: Panov Attack, Modern Defense': np.int64(256),
#  'Caro-Kann Defense: Panov Attack, Modern Defense, Mieses Line': np.int64(257),
#  'Caro-Kann Defense: Rasa-Studier Gambit': np.int64(258),
#  'Caro-Kann Defense: Spike Variation': np.int64(259),
#  'Caro-Kann Defense: Tartakower Variation': np.int64(260),
#  'Caro-Kann Defense: Toikkanen Gambit': np.int64(261),
#  'Caro-Kann Defense: Two Knights Attack': np.int64(262),
#  'Caro-Kann Defense: Two Knights Attack, Mindeno Variation': np.int64(263),
#  'Caro-Kann Defense: Two Knights Attack, Mindeno Variation, Exchange Line': np.int64(264),
#  'Caro-Kann Defense: Two Knights Attack, Mindeno Variation, Retreat Line': np.int64(265),
#  'Caro-Kann Defense: Ulysses Gambit': np.int64(266),
#  'Caro-Kann Defense: von Hennig Gambit': np.int64(267),
#  'Carr Defense': np.int64(268),
#  'Carr Defense: Zilbermints Gambit': np.int64(269),
#  'Catalan Opening': np.int64(270),
#  'Catalan Opening: Closed Variation': np.int64(271),
#  'Catalan Opening: Closed Variation, Traditional Variation': np.int64(272),
#  'Catalan Opening: Closed, 7.Qc2 c6 8.b3': np.int64(273),
#  'Catalan Opening: Closed, Main Line': np.int64(274),
#  'Catalan Opening: Open Defense': np.int64(275),
#  'Catalan Opening: Open Defense, Classical Line': np.int64(276),
#  'Catalan Opening: Open Defense, Tarrasch Defense': np.int64(277),
#  'Center Game': np.int64(278),
#  'Center Game #2': np.int64(279),
#  'Center Game Accepted': np.int64(280),
#  'Center Game: Berger Variation': np.int64(281),
#  'Center Game: Charousek Variation': np.int64(282),
#  'Center Game: Halasz-McDonnell Gambit': np.int64(283),
#  'Center Game: Halasz-McDonnell Gambit, Crocodile Variation': np.int64(284),
#  'Center Game: Hall Variation': np.int64(285),
#  'Center Game: Kieseritzky Variation': np.int64(286),
#  'Center Game: Kieseritzky Variation #2': np.int64(287),
#  'Center Game: Kieseritzky Variation #3': np.int64(288),
#  'Center Game: Kieseritzky Variation #4': np.int64(289),
#  'Center Game: Lanc-Arnold Gambit': np.int64(290),
#  'Center Game: Lanc-Arnold Gambit, Schippler Gambit': np.int64(291),
#  'Center Game: Normal Variation': np.int64(292),
#  'Center Game: Paulsen Attack Variation': np.int64(293),
#  'Center Game: Ross Gambit': np.int64(294),
#  "Center Game: l'Hermet Variation": np.int64(295),
#  'Center Game: von der Lasa Gambit': np.int64(296),
#  'Clemenz Opening': np.int64(297),
#  'Clemenz Opening: Spike Lee Gambit': np.int64(298),
#  'Colle System': np.int64(299),
#  'Colle System #2': np.int64(300),
#  'Colle System: Rhamphorhynchus Variation': np.int64(301),
#  'Colle System: Traditional Colle': np.int64(302),
#  'Crab Opening': np.int64(303),
#  'Creepy Crawly Formation: Classical Defense': np.int64(304),
#  'Czech Defense': np.int64(305),
#  'Danish Gambit': np.int64(306),
#  'Danish Gambit Accepted': np.int64(307),
#  'Danish Gambit Accepted, Chigorin Defense': np.int64(308),
#  'Danish Gambit Accepted, Classical Defense': np.int64(309),
#  'Danish Gambit Accepted, Copenhagen Defense': np.int64(310),
#  'Danish Gambit Accepted, Schlechter Defense': np.int64(311),
#  'Danish Gambit Declined, Sorensen Defense': np.int64(312),
#  'Doery Defense': np.int64(313),
#  'Dresden Opening: The Goblin': np.int64(314),
#  'Duras Gambit': np.int64(315),
#  'Dutch Defense': np.int64(316),
#  'Dutch Defense: Alapin Variation': np.int64(317),
#  'Dutch Defense: Blackburne Variation': np.int64(318),
#  "Dutch Defense: Blackmar's Second Gambit": np.int64(319),
#  'Dutch Defense: Bladel Variation': np.int64(320),
#  'Dutch Defense: Classical Variation': np.int64(321),
#  'Dutch Defense: Classical Variation, Huisl Variation': np.int64(322),
#  'Dutch Defense: Classical Variation, Ilyin-Zhenevsky Variation': np.int64(323),
#  'Dutch Defense: Classical Variation, Ilyin-Zhenevsky Variation, Alatortsev-Lisitsyn Line': np.int64(324),
#  'Dutch Defense: Classical Variation, Ilyin-Zhenevsky Variation, Modern Main Line': np.int64(325),
#  'Dutch Defense: Classical Variation, Stonewall Variation': np.int64(326),
#  'Dutch Defense: Fianchetto Attack': np.int64(327),
#  'Dutch Defense: Fianchetto Variation': np.int64(328),
#  'Dutch Defense: Hopton Attack': np.int64(329),
#  'Dutch Defense: Kingfisher Gambit': np.int64(330),
#  'Dutch Defense: Korchnoi Attack': np.int64(331),
#  'Dutch Defense: Krause Variation': np.int64(332),
#  'Dutch Defense: Krejcik Gambit': np.int64(333),
#  'Dutch Defense: Leningrad Variation': np.int64(334),
#  'Dutch Defense: Leningrad Variation, Matulovic Variation': np.int64(335),
#  'Dutch Defense: Leningrad Variation, Warsaw Variation': np.int64(336),
#  'Dutch Defense: Nimzo-Dutch Variation': np.int64(337),
#  'Dutch Defense: Nimzo-Dutch Variation, Alekhine Variation': np.int64(338),
#  'Dutch Defense: Normal Variation': np.int64(339),
#  "Dutch Defense: Queen's Knight Variation": np.int64(340),
#  'Dutch Defense: Raphael Variation': np.int64(341),
#  'Dutch Defense: Rubinstein Variation': np.int64(342),
#  'Dutch Defense: Semi-Leningrad Variation': np.int64(343),
#  'Dutch Defense: Staunton Gambit': np.int64(344),
#  'Dutch Defense: Staunton Gambit Accepted': np.int64(345),
#  'Dutch Defense: Staunton Gambit, American Attack': np.int64(346),
#  'Dutch Defense: Staunton Gambit, Nimzowitsch Variation': np.int64(347),
#  'Dutch Defense: Staunton Gambit, Tartakower Variation': np.int64(348),
#  'Dutch Defense: Stonewall Variation, Modern Variation': np.int64(349),
#  'Dutch Defense: Stonewall, with Nc3': np.int64(350),
#  'East Indian Defense': np.int64(351),
#  'Elephant Gambit': np.int64(352),
#  'Elephant Gambit: Maroczy Gambit': np.int64(353),
#  'Elephant Gambit: Paulsen Countergambit': np.int64(354),
#  'Elephant Gambit: Wasp Variation': np.int64(355),
#  'English Defense': np.int64(356),
#  'English Defense #2': np.int64(357),
#  'English Defense: Eastbourne Gambit': np.int64(358),
#  'English Opening': np.int64(359),
#  'English Opening: 2.g4': np.int64(360),
#  'English Opening: Achilles-Omega Gambit': np.int64(361),
#  'English Opening: Adorjan Defense': np.int64(362),
#  'English Opening: Agincourt Defense': np.int64(363),
#  'English Opening: Agincourt Defense #2': np.int64(364),
#  'English Opening: Agincourt Defense #3': np.int64(365),
#  'English Opening: Agincourt Defense, Bogoljubov Defense': np.int64(366),
#  'English Opening: Agincourt Defense, Catalan Defense': np.int64(367),
#  'English Opening: Agincourt Defense, Catalan Defense Accepted': np.int64(368),
#  'English Opening: Agincourt Defense, Catalan Defense, Semi-Slav Defense': np.int64(369),
#  'English Opening: Agincourt Defense, Keres Defense': np.int64(370),
#  'English Opening: Agincourt Defense, Kurajica Defense': np.int64(371),
#  'English Opening: Agincourt Defense, Neo-Catalan Declined': np.int64(372),
#  'English Opening: Agincourt Defense, Tarrasch Defense': np.int64(373),
#  'English Opening: Agincourt Defense, Wimpy System': np.int64(374),
#  'English Opening: Anglo-Dutch Defense': np.int64(375),
#  'English Opening: Anglo-Dutch Defense, Hickmann Gambit': np.int64(376),
#  'English Opening: Anglo-Gruenfeld Defense': np.int64(377),
#  'English Opening: Anglo-Indian Defense': np.int64(378),
#  'English Opening: Anglo-Indian Defense, Anglo-Gruenfeld Variation': np.int64(379),
#  'English Opening: Anglo-Indian Defense, Anglo-Gruenfeld Variation #3': np.int64(380),
#  'English Opening: Anglo-Indian Defense, Anti-Anti-Gruenfeld': np.int64(381),
#  'English Opening: Anglo-Indian Defense, Flohr-Mikenas-Carls Variation, Nei Gambit': np.int64(382),
#  'English Opening: Anglo-Indian Defense, Hedgehog System': np.int64(383),
#  "English Opening: Anglo-Indian Defense, King's Indian Formation": np.int64(384),
#  "English Opening: Anglo-Indian Defense, King's Knight Variation": np.int64(385),
#  'English Opening: Anglo-Indian Defense, Nimzo-English': np.int64(386),
#  'English Opening: Anglo-Indian Defense, Old Indian Formation': np.int64(387),
#  "English Opening: Anglo-Indian Defense, Queen's Indian Formation": np.int64(388),
#  "English Opening: Anglo-Indian Defense, Queen's Indian Variation": np.int64(389),
#  "English Opening: Anglo-Indian Defense, Queen's Knight Variation": np.int64(390),
#  'English Opening: Anglo-Indian Defense, Scandinavian Defense': np.int64(391),
#  'English Opening: Anglo-Indian Defense, Scandinavian Defense, Exchange Variation': np.int64(392),
#  'English Opening: Anglo-Indian Defense, Slav Formation': np.int64(393),
#  'English Opening: Anglo-Lithuanian Variation': np.int64(394),
#  'English Opening: Anglo-Scandinavian Defense': np.int64(395),
#  'English Opening: Anglo-Scandinavian Defense, Loehn Gambit': np.int64(396),
#  'English Opening: Anglo-Scandinavian Defense, Malvinas Variation': np.int64(397),
#  'English Opening: Anglo-Scandinavian Defense, Schulz Gambit': np.int64(398),
#  'English Opening: Carls-Bremen System': np.int64(399),
#  'English Opening: Caro-Kann Defensive System': np.int64(400),
#  'English Opening: Four Knights System, Nimzowitsch Variation': np.int64(401),
#  'English Opening: Great Snake Variation': np.int64(402),
#  'English Opening: Jaenisch Gambit': np.int64(403),
#  "English Opening: King's English Variation": np.int64(404),
#  "English Opening: King's English Variation, Closed System, Full Symmetry": np.int64(405),
#  "English Opening: King's English Variation, Four Knights Variation #2": np.int64(406),
#  "English Opening: King's English Variation, Four Knights Variation, Bradley Beach Variation": np.int64(407),
#  "English Opening: King's English Variation, Four Knights Variation, Fianchetto Line": np.int64(408),
#  "English Opening: King's English Variation, Four Knights Variation, Flexible Line": np.int64(409),
#  "English Opening: King's English Variation, Four Knights Variation, Korchnoi Line": np.int64(410),
#  "English Opening: King's English Variation, Four Knights Variation, Quiet Line": np.int64(411),
#  "English Opening: King's English Variation, Four Knights Variation, Quiet Line #3": np.int64(412),
#  "English Opening: King's English Variation, Keres Defense": np.int64(413),
#  "English Opening: King's English Variation, Kramnik-Shirov Counterattack": np.int64(414),
#  "English Opening: King's English Variation, Nimzowitsch Variation": np.int64(415),
#  "English Opening: King's English Variation, Nimzowitsch-Flohr Variation": np.int64(416),
#  "English Opening: King's English Variation, Reversed Closed Sicilian": np.int64(417),
#  "English Opening: King's English Variation, Reversed Sicilian": np.int64(418),
#  "English Opening: King's English Variation, Smyslov Defense": np.int64(419),
#  "English Opening: King's English Variation, Taimanov Variation": np.int64(420),
#  "English Opening: King's English Variation, Three Knights System": np.int64(421),
#  "English Opening: King's English Variation, Troger Defense": np.int64(422),
#  "English Opening: King's English Variation, Two Knights Variation": np.int64(423),
#  "English Opening: King's English Variation, Two Knights Variation, Fianchetto Line": np.int64(424),
#  "English Opening: King's English Variation, Two Knights Variation, Keres Variation": np.int64(425),
#  "English Opening: King's English Variation, Two Knights Variation, Reversed Dragon": np.int64(426),
#  "English Opening: King's English Variation, Two Knights Variation, Smyslov System": np.int64(427),
#  'English Opening: Mikenas-Carls Variation': np.int64(428),
#  'English Opening: Mikenas-Carls Variation #2': np.int64(429),
#  'English Opening: Mikenas-Carls Variation #3': np.int64(430),
#  'English Opening: Mikenas-Carls, Sicilian': np.int64(431),
#  'English Opening: Myers Variation': np.int64(432),
#  'English Opening: Neo-Catalan': np.int64(433),
#  'English Opening: Neo-Catalan Declined': np.int64(434),
#  'English Opening: Romanishin Gambit': np.int64(435),
#  'English Opening: Symmetrical Variation': np.int64(436),
#  'English Opening: Symmetrical Variation, Anti-Benoni Variation': np.int64(437),
#  'English Opening: Symmetrical Variation, Anti-Benoni Variation, Spielmann Defense': np.int64(438),
#  'English Opening: Symmetrical Variation, Botvinnik System': np.int64(439),
#  'English Opening: Symmetrical Variation, Botvinnik System Reversed': np.int64(440),
#  'English Opening: Symmetrical Variation, Double Fianchetto': np.int64(441),
#  'English Opening: Symmetrical Variation, Duchamp Variation': np.int64(442),
#  'English Opening: Symmetrical Variation, Fianchetto Variation': np.int64(443),
#  'English Opening: Symmetrical Variation, Four Knights Variation': np.int64(444),
#  'English Opening: Symmetrical Variation, Full Symmetry Line': np.int64(445),
#  'English Opening: Symmetrical Variation, Hedgehog Defense': np.int64(446),
#  'English Opening: Symmetrical Variation, Mecking Variation': np.int64(447),
#  'English Opening: Symmetrical Variation, Normal Variation': np.int64(448),
#  'English Opening: Symmetrical Variation, Symmetrical Variation': np.int64(449),
#  'English Opening: Symmetrical Variation, Three Knights Variation': np.int64(450),
#  'English Opening: Symmetrical Variation, Two Knights Line': np.int64(451),
#  'English Opening: Symmetrical Variation, Two Knights Variation': np.int64(452),
#  'English Opening: The Whale': np.int64(453),
#  'English Opening: Wade Gambit': np.int64(454),
#  'English Opening: Wing Gambit': np.int64(455),
#  'English Orangutan': np.int64(456),
#  'English Rat: Pounds Gambit': np.int64(457),
#  'Englund Gambit': np.int64(458),
#  'Englund Gambit Complex Declined': np.int64(459),
#  'Englund Gambit Complex Declined, Diemer Counterattack': np.int64(460),
#  'Englund Gambit Complex: Englund Gambit': np.int64(461),
#  'Englund Gambit Complex: Felbecker Gambit': np.int64(462),
#  'Englund Gambit Complex: Hartlaub-Charlick Gambit': np.int64(463),
#  'Englund Gambit Complex: Mosquito Gambit': np.int64(464),
#  'Englund Gambit Complex: Soller Gambit': np.int64(465),
#  'Englund Gambit Complex: Soller Gambit Deferred': np.int64(466),
#  'Englund Gambit Complex: Stockholm Variation': np.int64(467),
#  'Englund Gambit Complex: Zilbermints Gambit': np.int64(468),
#  'Englund Gambit Complex: Zilbermints Gambit II': np.int64(469),
#  'Englund Gambit Declined, Reversed Alekhine': np.int64(470),
#  'Englund Gambit Declined, Reversed Brooklyn': np.int64(471),
#  'Englund Gambit Declined, Reversed French': np.int64(472),
#  'Englund Gambit Declined, Reversed Krebs': np.int64(473),
#  'Englund Gambit Declined, Reversed Mokele Mbembe': np.int64(474),
#  'Four Knights Game': np.int64(475),
#  'Four Knights Game: Double Spanish': np.int64(476),
#  'Four Knights Game: Double Spanish, with 5.O-O': np.int64(477),
#  'Four Knights Game: Gunsberg Variation': np.int64(478),
#  'Four Knights Game: Halloween Gambit': np.int64(479),
#  'Four Knights Game: Italian Variation': np.int64(480),
#  'Four Knights Game: Italian Variation, Noa Gambit': np.int64(481),
#  'Four Knights Game: Marshall Variation': np.int64(482),
#  'Four Knights Game: Nimzowitsch (Paulsen)': np.int64(483),
#  'Four Knights Game: Ranken Variation': np.int64(484),
#  'Four Knights Game: Rubinstein Countergambit, 5.Be2': np.int64(485),
#  'Four Knights Game: Rubinstein Countergambit, Henneberger Variation': np.int64(486),
#  'Four Knights Game: Scotch Variation': np.int64(487),
#  'Four Knights Game: Scotch Variation Accepted': np.int64(488),
#  'Four Knights Game: Scotch Variation, Belgrade Gambit': np.int64(489),
#  'Four Knights Game: Scotch Variation, Krause Gambit': np.int64(490),
#  'Four Knights Game: Scotch Variation, Oxford Gambit': np.int64(491),
#  'Four Knights Game: Scotch Variation, Schmid Defense': np.int64(492),
#  'Four Knights Game: Spanish Variation': np.int64(493),
#  'Four Knights Game: Spanish Variation, Classical Variation': np.int64(494),
#  'Four Knights Game: Spanish Variation, Rubinstein Variation': np.int64(495),
#  'Four Knights Game: Spanish Variation, Rubinstein Variation #2': np.int64(496),
#  'Four Knights Game: Spanish Variation, Rubinstein Variation Accepted': np.int64(497),
#  'Four Knights Game: Spanish Variation, Symmetrical Variation #3': np.int64(498),
#  'Four Knights Game: Spielmann Variation': np.int64(499),
#  'Franco-Benoni Defense': np.int64(500),
#  'French Defense': np.int64(501),
#  'French Defense #2': np.int64(502),
#  'French Defense: Advance Variation': np.int64(503),
#  'French Defense: Advance Variation #2': np.int64(504),
#  'French Defense: Advance Variation #3': np.int64(505),
#  'French Defense: Advance Variation #4': np.int64(506),
#  'French Defense: Advance Variation, Euwe Variation': np.int64(507),
#  'French Defense: Advance Variation, Extended Bishop Swap': np.int64(508),
#  'French Defense: Advance Variation, Frenkel Gambit': np.int64(509),
#  'French Defense: Advance Variation, Lputian Variation': np.int64(510),
#  'French Defense: Advance Variation, Main Line': np.int64(511),
#  'French Defense: Advance Variation, Milner-Barry Gambit': np.int64(512),
#  'French Defense: Advance Variation, Nimzowitsch Attack': np.int64(513),
#  'French Defense: Advance Variation, Nimzowitsch System': np.int64(514),
#  'French Defense: Advance Variation, Paulsen Attack': np.int64(515),
#  'French Defense: Advance Variation, Ruisdonk Gambit': np.int64(516),
#  'French Defense: Advance Variation, Wade Variation': np.int64(517),
#  'French Defense: Advance, Steinitz Variation': np.int64(518),
#  'French Defense: Alapin Gambit': np.int64(519),
#  'French Defense: Alekhine-Chatard Attack': np.int64(520),
#  'French Defense: Alekhine-Chatard Attack, Albin-Chatard Gambit': np.int64(521),
#  'French Defense: Alekhine-Chatard Attack, Breyer Variation': np.int64(522),
#  'French Defense: Alekhine-Chatard Attack, Maroczy Variation': np.int64(523),
#  'French Defense: Baeuerle Gambit': np.int64(524),
#  'French Defense: Banzai-Leong Gambit': np.int64(525),
#  'French Defense: Bird Invitation': np.int64(526),
#  'French Defense: Burn Variation': np.int64(527),
#  'French Defense: Carlson Gambit': np.int64(528),
#  'French Defense: Chigorin Variation': np.int64(529),
#  'French Defense: Classical Variation': np.int64(530),
#  'French Defense: Classical Variation, Alapin Variation': np.int64(531),
#  'French Defense: Classical Variation, Burn Variation, Main Line': np.int64(532),
#  'French Defense: Classical Variation, Burn Variation, Morozevich Line': np.int64(533),
#  'French Defense: Classical Variation, Delayed Exchange Variation': np.int64(534),
#  'French Defense: Classical Variation, Normal Variation': np.int64(535),
#  'French Defense: Classical Variation, Pollock Variation': np.int64(536),
#  'French Defense: Classical Variation, Richter Attack': np.int64(537),
#  'French Defense: Classical Variation, Richter Attack #2': np.int64(538),
#  'French Defense: Classical Variation, Rubinstein Variation': np.int64(539),
#  'French Defense: Classical Variation, Steinitz Variation': np.int64(540),
#  'French Defense: Classical Variation, Svenonius Variation': np.int64(541),
#  'French Defense: Classical Variation, Swiss Variation': np.int64(542),
#  'French Defense: Classical Variation, Tarrasch Variation': np.int64(543),
#  'French Defense: Classical Variation, Tartakower Variation': np.int64(544),
#  'French Defense: Classical Variation, Vistaneckis (Nimzowitsch) Variation': np.int64(545),
#  'French Defense: Diemer-Duhm Gambit': np.int64(546),
#  'French Defense: Exchange Variation': np.int64(547),
#  'French Defense: Exchange Variation, Monte Carlo Variation': np.int64(548),
#  'French Defense: Exchange Variation, Svenonius Variation': np.int64(549),
#  'French Defense: Franco-Hiva Gambit I': np.int64(550),
#  'French Defense: Franco-Hiva Gambit I Accepted': np.int64(551),
#  'French Defense: Franco-Hiva Gambit II': np.int64(552),
#  'French Defense: Franco-Hiva Gambit III': np.int64(553),
#  'French Defense: Guimard Variation, Thunderbunny Variation': np.int64(554),
#  'French Defense: Henneberger Variation': np.int64(555),
#  'French Defense: Horwitz Attack': np.int64(556),
#  'French Defense: Horwitz Attack, Papa-Ticulat Gambit': np.int64(557),
#  "French Defense: King's Indian Attack": np.int64(558),
#  'French Defense: Knight Variation': np.int64(559),
#  'French Defense: La Bourdonnais Variation': np.int64(560),
#  'French Defense: La Bourdonnais Variation, Reuter Gambit': np.int64(561),
#  'French Defense: MacCutcheon Variation': np.int64(562),
#  'French Defense: MacCutcheon Variation, Bernstein Variation': np.int64(563),
#  'French Defense: MacCutcheon Variation, Chigorin Variation': np.int64(564),
#  'French Defense: MacCutcheon Variation, Exchange Variation': np.int64(565),
#  'French Defense: MacCutcheon Variation, Lasker Variation': np.int64(566),
#  'French Defense: MacCutcheon Variation, Tartakower Variation': np.int64(567),
#  'French Defense: MacCutcheon Variation, Wolf Gambit': np.int64(568),
#  'French Defense: MacCutcheon, Advance Variation': np.int64(569),
#  'French Defense: Marshall Variation': np.int64(570),
#  'French Defense: Mediterranean Defense': np.int64(571),
#  'French Defense: Morphy Gambit': np.int64(572),
#  'French Defense: Normal Variation': np.int64(573),
#  'French Defense: Paulsen Variation': np.int64(574),
#  'French Defense: Pelikan Variation': np.int64(575),
#  'French Defense: Perseus Gambit': np.int64(576),
#  "French Defense: Queen's Knight": np.int64(577),
#  'French Defense: Reti-Spielmann Attack': np.int64(578),
#  'French Defense: Rubinstein Variation': np.int64(579),
#  'French Defense: Rubinstein Variation, Blackburne Defense': np.int64(580),
#  'French Defense: Rubinstein Variation, Ellis Gambit': np.int64(581),
#  'French Defense: Rubinstein Variation, Fort Knox Variation': np.int64(582),
#  'French Defense: Rubinstein Variation, Kasparov Attack': np.int64(583),
#  'French Defense: Rubinstein Variation, Maric Variation': np.int64(584),
#  'French Defense: Schlechter Variation': np.int64(585),
#  'French Defense: Steiner Variation': np.int64(586),
#  'French Defense: Steinitz Attack': np.int64(587),
#  'French Defense: Steinitz Variation #2': np.int64(588),
#  'French Defense: Steinitz Variation, Boleslavsky Variation': np.int64(589),
#  'French Defense: Steinitz Variation, Gledhill Attack': np.int64(590),
#  'French Defense: Tarrasch Variation': np.int64(591),
#  'French Defense: Tarrasch Variation, Chistyakov Defense': np.int64(592),
#  'French Defense: Tarrasch Variation, Closed Variation': np.int64(593),
#  'French Defense: Tarrasch Variation, Closed Variation #2': np.int64(594),
#  'French Defense: Tarrasch Variation, Closed Variation, Main Line': np.int64(595),
#  'French Defense: Tarrasch Variation, Guimard Defense': np.int64(596),
#  'French Defense: Tarrasch Variation, Guimard Defense, Main Line': np.int64(597),
#  'French Defense: Tarrasch Variation, Haberditz Variation': np.int64(598),
#  'French Defense: Tarrasch Variation, Leningrad Variation': np.int64(599),
#  'French Defense: Tarrasch Variation, Modern System': np.int64(600),
#  'French Defense: Tarrasch Variation, Morozevich Variation': np.int64(601),
#  'French Defense: Tarrasch Variation, Open System': np.int64(602),
#  'French Defense: Tarrasch Variation, Open System, Advance Line': np.int64(603),
#  'French Defense: Tarrasch Variation, Open System, Euwe-Keres Line': np.int64(604),
#  'French Defense: Tarrasch Variation, Open System, Main Line': np.int64(605),
#  'French Defense: Tarrasch Variation, Open System, Suechting Line': np.int64(606),
#  'French Defense: Tarrasch Variation, Pawn Center Variation': np.int64(607),
#  'French Defense: Tarrasch, Eliskases Variation': np.int64(608),
#  'French Defense: Tarrasch, Open, 4.exd5 exd5': np.int64(609),
#  'French Defense: Two Knights Variation': np.int64(610),
#  'French Defense: Winawer Variation': np.int64(611),
#  'French Defense: Winawer Variation, Advance Variation': np.int64(612),
#  'French Defense: Winawer Variation, Advance Variation #2': np.int64(613),
#  'French Defense: Winawer Variation, Advance Variation #3': np.int64(614),
#  'French Defense: Winawer Variation, Advance Variation, Moscow Variation': np.int64(615),
#  'French Defense: Winawer Variation, Alekhine Gambit Accepted': np.int64(616),
#  'French Defense: Winawer Variation, Alekhine Gambit, Kan Variation': np.int64(617),
#  'French Defense: Winawer Variation, Alekhine-Maroczy Gambit': np.int64(618),
#  'French Defense: Winawer Variation, Bogoljubov Variation': np.int64(619),
#  'French Defense: Winawer Variation, Classical Variation': np.int64(620),
#  'French Defense: Winawer Variation, Delayed Exchange Variation': np.int64(621),
#  'French Defense: Winawer Variation, Fingerslip Variation': np.int64(622),
#  'French Defense: Winawer Variation, Kondratiyev Variation': np.int64(623),
#  'French Defense: Winawer Variation, Maroczy-Wallis Variation': np.int64(624),
#  'French Defense: Winawer Variation, Petrosian Variation': np.int64(625),
#  'French Defense: Winawer Variation, Poisoned Pawn Variation': np.int64(626),
#  'French Defense: Winawer Variation, Positional Variation': np.int64(627),
#  'French Defense: Winawer Variation, Retreat Variation': np.int64(628),
#  'French Defense: Winawer Variation, Retreat Variation, Armenian Line': np.int64(629),
#  'French Defense: Winawer Variation, Winckelmann-Riemer Gambit': np.int64(630),
#  'French Defense: Wing Gambit': np.int64(631),
#  "Gedult's Opening": np.int64(632),
#  'Giuoco Piano': np.int64(633),
#  'Global Opening': np.int64(634),
#  'Goldsmith Defense': np.int64(635),
#  'Goldsmith Defense: Picklepuss Defense': np.int64(636),
#  'Grob Opening': np.int64(637),
#  'Grob Opening: Alessi Gambit': np.int64(638),
#  'Grob Opening: Double Grob': np.int64(639),
#  'Grob Opening: Grob Gambit': np.int64(640),
#  'Grob Opening: Grob Gambit Declined': np.int64(641),
#  'Grob Opening: Grob Gambit, Fritz Gambit': np.int64(642),
#  'Grob Opening: Grob Gambit, Richter-Grob Gambit': np.int64(643),
#  'Grob Opening: Keene Defense': np.int64(644),
#  'Grob Opening: London Defense': np.int64(645),
#  'Grob Opening: Romford Countergambit': np.int64(646),
#  'Grob Opening: Spike Attack': np.int64(647),
#  'Grob Opening: Spike, Hurst Attack': np.int64(648),
#  'Gruenfeld Defense': np.int64(649),
#  'Gruenfeld Defense: Brinckmann Attack': np.int64(650),
#  'Gruenfeld Defense: Brinckmann Attack, Gruenfeld Gambit': np.int64(651),
#  'Gruenfeld Defense: Counterthrust Variation': np.int64(652),
#  'Gruenfeld Defense: Exchange Variation': np.int64(653),
#  'Gruenfeld Defense: Exchange Variation, Classical Variation': np.int64(654),
#  'Gruenfeld Defense: Exchange Variation, Modern Exchange Variation': np.int64(655),
#  "Gruenfeld Defense: Exchange Variation, Modern Exchange Variation, Kramnik's Line": np.int64(656),
#  'Gruenfeld Defense: Exchange Variation, Spassky Variation': np.int64(657),
#  'Gruenfeld Defense: Lutikov Variation': np.int64(658),
#  'Gruenfeld Defense: Makogonov Variation': np.int64(659),
#  'Gruenfeld Defense: Opocensky Variation': np.int64(660),
#  'Gruenfeld Defense: Russian Variation': np.int64(661),
#  'Gruenfeld Defense: Russian Variation, Accelerated Variation': np.int64(662),
#  'Gruenfeld Defense: Smyslov Defense': np.int64(663),
#  'Gruenfeld Defense: Stockholm Variation': np.int64(664),
#  'Gruenfeld Defense: Three Knights Variation': np.int64(665),
#  'Gruenfeld Defense: Three Knights Variation #2': np.int64(666),
#  'Gruenfeld Defense: Three Knights Variation, Burille Variation': np.int64(667),
#  'Gruenfeld Defense: Three Knights Variation, Burille Variation, Reversed Tarrasch': np.int64(668),
#  'Gruenfeld Defense: Three Knights Variation, Hungarian Attack': np.int64(669),
#  'Gruenfeld Defense: Three Knights Variation, Hungarian Variation': np.int64(670),
#  'Gruenfeld Defense: Three Knights Variation, Paris Variation': np.int64(671),
#  'Gruenfeld Defense: Three Knights Variation, Petrosian System': np.int64(672),
#  'Gruenfeld Defense: Three Knights Variation, Vienna Variation': np.int64(673),
#  'Guatemala Defense': np.int64(674),
#  'Gunderam Defense': np.int64(675),
#  'Hippopotamus Defense': np.int64(676),
#  'Hippopotamus Defense #2': np.int64(677),
#  'Horwitz Defense': np.int64(678),
#  'Horwitz Defense: Dutch Defense, Bellon Gambit': np.int64(679),
#  'Horwitz Defense: Zilbermints Gambit': np.int64(680),
#  'Hungarian Opening': np.int64(681),
#  'Hungarian Opening: Catalan Formation': np.int64(682),
#  'Hungarian Opening: Dutch Defense': np.int64(683),
#  'Hungarian Opening: Indian Defense': np.int64(684),
#  'Hungarian Opening: Myers Defense': np.int64(685),
#  'Hungarian Opening: Reversed Alekhine': np.int64(686),
#  'Hungarian Opening: Reversed Modern Defense': np.int64(687),
#  'Hungarian Opening: Reversed Norwegian Defense': np.int64(688),
#  'Hungarian Opening: Sicilian Invitation': np.int64(689),
#  'Hungarian Opening: Slav Formation': np.int64(690),
#  'Hungarian Opening: Symmetrical Variation': np.int64(691),
#  'Hungarian Opening: Van Kuijk Gambit': np.int64(692),
#  'Indian Game': np.int64(693),
#  'Indian Game: 3.Qb3': np.int64(694),
#  'Indian Game: Anti-Gruenfeld, Advance Variation': np.int64(695),
#  'Indian Game: Anti-Gruenfeld, Alekhine Variation': np.int64(696),
#  'Indian Game: Anti-Gruenfeld, Alekhine Variation, Leko Gambit': np.int64(697),
#  'Indian Game: Anti-Nimzo-Indian': np.int64(698),
#  'Indian Game: Budapest Defense': np.int64(699),
#  "Indian Game: Colle System, King's Indian Variation": np.int64(700),
#  'Indian Game: Czech-Indian': np.int64(701),
#  'Indian Game: Doery Indian': np.int64(702),
#  'Indian Game: Dzindzi-Indian Defense': np.int64(703),
#  'Indian Game: East Indian Defense': np.int64(704),
#  'Indian Game: Gedult Attack, Gedult Attack': np.int64(705),
#  'Indian Game: Gibbins-Wiedenhagen Gambit Accepted': np.int64(706),
#  "Indian Game: King's Indian Variation, Fianchetto Variation": np.int64(707),
#  'Indian Game: Knights Variation, Alburt-Miles Variation': np.int64(708),
#  'Indian Game: London System': np.int64(709),
#  'Indian Game: Maddigan Gambit': np.int64(710),
#  'Indian Game: Medusa Gambit': np.int64(711),
#  'Indian Game: Normal Variation': np.int64(712),
#  'Indian Game: Omega Gambit': np.int64(713),
#  'Indian Game: Omega Gambit, Arafat Gambit': np.int64(714),
#  'Indian Game: Paleface Attack, Blackmar-Diemer Gambit Deferred': np.int64(715),
#  'Indian Game: Pawn Push Variation': np.int64(716),
#  'Indian Game: Polish Variation': np.int64(717),
#  'Indian Game: Przepiorka Variation': np.int64(718),
#  'Indian Game: Pseudo-Benko': np.int64(719),
#  'Indian Game: Pyrenees Gambit': np.int64(720),
#  'Indian Game: Reversed Chigorin Defense': np.int64(721),
#  'Indian Game: Seirawan Attack': np.int64(722),
#  'Indian Game: Spielmann-Indian': np.int64(723),
#  'Indian Game: Tartakower Attack': np.int64(724),
#  'Indian Game: Wade-Tartakower Defense': np.int64(725),
#  'Indian Game: West Indian Defense': np.int64(726),
#  'Irish Gambit': np.int64(727),
#  'Italian Game': np.int64(728),
#  'Italian Game: Anti-Fried Liver Defense': np.int64(729),
#  "Italian Game: Bird's Attack": np.int64(730),
#  'Italian Game: Classical Variation': np.int64(731),
#  'Italian Game: Classical Variation #2': np.int64(732),
#  'Italian Game: Classical Variation, Albin Gambit': np.int64(733),
#  'Italian Game: Classical Variation, Alexandre Gambit': np.int64(734),
#  'Italian Game: Classical Variation, Center Attack': np.int64(735),
#  'Italian Game: Classical Variation, Center Holding Variation': np.int64(736),
#  'Italian Game: Classical Variation, Closed Variation': np.int64(737),
#  'Italian Game: Classical Variation, Giuoco Pianissimo': np.int64(738),
#  'Italian Game: Classical Variation, Greco Gambit': np.int64(739),
#  'Italian Game: Classical Variation, Greco Gambit, Anderssen Variation': np.int64(740),
#  'Italian Game: Classical Variation, Greco Gambit, Greco Variation': np.int64(741),
#  'Italian Game: Classical Variation, Greco Gambit, Main Line': np.int64(742),
#  'Italian Game: Classical Variation, Greco Gambit, Moeller-Therkatz Attack': np.int64(743),
#  'Italian Game: Classical Variation, Greco Gambit, Traditional Line': np.int64(744),
#  'Italian Game: Classical Variation, La Bourdonnais Variation': np.int64(745),
#  'Italian Game: Deutz Gambit': np.int64(746),
#  'Italian Game: Evans Gambit': np.int64(747),
#  'Italian Game: Evans Gambit Accepted': np.int64(748),
#  'Italian Game: Evans Gambit Declined': np.int64(749),
#  'Italian Game: Evans Gambit Declined, 5.a4': np.int64(750),
#  'Italian Game: Evans Gambit Declined, Cordel Variation': np.int64(751),
#  'Italian Game: Evans Gambit Declined, Showalter Variation': np.int64(752),
#  'Italian Game: Evans Gambit, Alapin-Steinitz Variation': np.int64(753),
#  'Italian Game: Evans Gambit, Anderssen Defense': np.int64(754),
#  'Italian Game: Evans Gambit, Anderssen Variation': np.int64(755),
#  'Italian Game: Evans Gambit, Anderssen Variation, Cordel Line': np.int64(756),
#  'Italian Game: Evans Gambit, Bronstein Defense': np.int64(757),
#  'Italian Game: Evans Gambit, Compromised Defense': np.int64(758),
#  'Italian Game: Evans Gambit, Fontaine Countergambit': np.int64(759),
#  'Italian Game: Evans Gambit, Harding Variation': np.int64(760),
#  'Italian Game: Evans Gambit, Laroche Variation': np.int64(761),
#  'Italian Game: Evans Gambit, Lasker Defense': np.int64(762),
#  'Italian Game: Evans Gambit, Main Line': np.int64(763),
#  'Italian Game: Evans Gambit, McDonnell Defense': np.int64(764),
#  'Italian Game: Evans Gambit, McDonnell Defense, Main Line': np.int64(765),
#  'Italian Game: Evans Gambit, Mieses Defense': np.int64(766),
#  'Italian Game: Evans Gambit, Morphy Attack': np.int64(767),
#  'Italian Game: Evans Gambit, Pierce Defense': np.int64(768),
#  'Italian Game: Evans Gambit, Slow Variation': np.int64(769),
#  'Italian Game: Evans Gambit, Stone-Ware Variation': np.int64(770),
#  'Italian Game: Evans Gambit, Waller Attack': np.int64(771),
#  'Italian Game: Giuoco Pianissimo': np.int64(772),
#  'Italian Game: Giuoco Pianissimo, Canal Variation': np.int64(773),
#  'Italian Game: Giuoco Pianissimo, Dubois Variation': np.int64(774),
#  'Italian Game: Giuoco Pianissimo, Italian Four Knights Variation': np.int64(775),
#  'Italian Game: Giuoco Pianissimo, Lucchini Gambit': np.int64(776),
#  'Italian Game: Giuoco Pianissimo, Normal': np.int64(777),
#  'Italian Game: Giuoco Piano, Aitken Variation': np.int64(778),
#  'Italian Game: Giuoco Piano, Bernstein Variation': np.int64(779),
#  "Italian Game: Giuoco Piano, Greco's Attack": np.int64(780),
#  'Italian Game: Giuoco Piano, Rosentreter Variation': np.int64(781),
#  'Italian Game: Hungarian Defense': np.int64(782),
#  'Italian Game: Hungarian Defense, Tartakower Variation': np.int64(783),
#  'Italian Game: Jerome Gambit': np.int64(784),
#  'Italian Game: Rosentreter Gambit': np.int64(785),
#  'Italian Game: Rousseau Gambit': np.int64(786),
#  'Italian Game: Schilling-Kostic Gambit': np.int64(787),
#  'Italian Game: Scotch Gambit': np.int64(788),
#  'Italian Game: Scotch Gambit Declined': np.int64(789),
#  'Italian Game: Scotch Gambit Declined #2': np.int64(790),
#  'Italian Game: Scotch Gambit, Anderssen Attack': np.int64(791),
#  'Italian Game: Scotch Gambit, Anderssen Attack, Main Line': np.int64(792),
#  'Italian Game: Scotch Gambit, Canal Variation': np.int64(793),
#  'Italian Game: Scotch Gambit, Double Gambit Accepted': np.int64(794),
#  'Italian Game: Scotch Gambit, Janowski Defense': np.int64(795),
#  'Italian Game: Scotch Gambit, Max Lange Attack': np.int64(796),
#  'Italian Game: Scotch Gambit, Max Lange Attack Accepted': np.int64(797),
#  'Italian Game: Scotch Gambit, Max Lange Attack, Spielmann Defense': np.int64(798),
#  'Italian Game: Scotch Gambit, Walbrodt-Baird Gambit': np.int64(799),
#  'Italian Game: Scotch Gambit, de Riviere Defense': np.int64(800),
#  'Italian Game: Two Knights Defense': np.int64(801),
#  'Italian Game: Two Knights Defense #2': np.int64(802),
#  'Italian Game: Two Knights Defense, Fried Liver Attack': np.int64(803),
#  'Italian Game: Two Knights Defense, Fritz Variation': np.int64(804),
#  'Italian Game: Two Knights Defense, Fritz, Gruber Variation': np.int64(805),
#  'Italian Game: Two Knights Defense, Kloss Gambit': np.int64(806),
#  'Italian Game: Two Knights Defense, Knight Attack': np.int64(807),
#  'Italian Game: Two Knights Defense, Knight Attack, Normal Variation': np.int64(808),
#  'Italian Game: Two Knights Defense, Lolli Attack': np.int64(809),
#  'Italian Game: Two Knights Defense, Maroczy Variation': np.int64(810),
#  'Italian Game: Two Knights Defense, Max Lange Attack': np.int64(811),
#  'Italian Game: Two Knights Defense, Max Lange Attack, Krause Variation': np.int64(812),
#  "Italian Game: Two Knights Defense, Modern Bishop's Opening": np.int64(813),
#  'Italian Game: Two Knights Defense, Open Variation': np.int64(814),
#  'Italian Game: Two Knights Defense, Perreux Variation': np.int64(815),
#  'Italian Game: Two Knights Defense, Pincus Variation': np.int64(816),
#  'Italian Game: Two Knights Defense, Polerio Defense': np.int64(817),
#  'Italian Game: Two Knights Defense, Polerio Defense, Bishop Check Line': np.int64(818),
#  'Italian Game: Two Knights Defense, Polerio Defense, Bogoljubov Variation': np.int64(819),
#  'Italian Game: Two Knights Defense, Polerio Defense, Goering Variation': np.int64(820),
#  'Italian Game: Two Knights Defense, Polerio Defense, Kieseritzky Variation': np.int64(821),
#  'Italian Game: Two Knights Defense, Polerio Defense, Suhle Defense': np.int64(822),
#  'Italian Game: Two Knights Defense, Ponziani-Steinitz Gambit': np.int64(823),
#  'Italian Game: Two Knights Defense, Steinitz Variation': np.int64(824),
#  'Italian Game: Two Knights Defense, Traxler Counterattack': np.int64(825),
#  'Italian Game: Two Knights Defense, Traxler Counterattack, Bishop Sacrifice Line': np.int64(826),
#  'Italian Game: Two Knights Defense, Traxler Counterattack, Knight Sacrifice Line': np.int64(827),
#  'Italian Game: Two Knights Defense, Ulvestad Variation': np.int64(828),
#  'Italian Game: Two Knights Defense, de Riviere Gambit': np.int64(829),
#  'Kadas Opening': np.int64(830),
#  'Kadas Opening: Schneider Gambit': np.int64(831),
#  'Kangaroo Defense': np.int64(832),
#  'Kangaroo Defense: Keres Defense, Transpositional Variation': np.int64(833),
#  "King's Gambit": np.int64(834),
#  "King's Gambit Accepted": np.int64(835),
#  "King's Gambit Accepted, Abbazia Defense": np.int64(836),
#  "King's Gambit Accepted, Allgaier Gambit": np.int64(837),
#  "King's Gambit Accepted, Australian Gambit": np.int64(838),
#  "King's Gambit Accepted, Becker Defense": np.int64(839),
#  "King's Gambit Accepted, Bishop's Gambit": np.int64(840),
#  "King's Gambit Accepted, Bishop's Gambit, Anderssen Defense": np.int64(841),
#  "King's Gambit Accepted, Bishop's Gambit, Bledow Countergambit": np.int64(842),
#  "King's Gambit Accepted, Bishop's Gambit, Bogoljubov Defense": np.int64(843),
#  "King's Gambit Accepted, Bishop's Gambit, Bogoljubov Variation": np.int64(844),
#  "King's Gambit Accepted, Bishop's Gambit, Cozio Defense": np.int64(845),
#  "King's Gambit Accepted, Bishop's Gambit, Lopez Defense": np.int64(846),
#  "King's Gambit Accepted, Bishop's Gambit, Maurian Defense": np.int64(847),
#  "King's Gambit Accepted, Blachly Gambit": np.int64(848),
#  "King's Gambit Accepted, Bonsch-Osmolovsky Variation": np.int64(849),
#  "King's Gambit Accepted, Breyer Gambit": np.int64(850),
#  "King's Gambit Accepted, Carrera Gambit": np.int64(851),
#  "King's Gambit Accepted, Cunningham Defense": np.int64(852),
#  "King's Gambit Accepted, Cunningham Defense, Bertin Gambit": np.int64(853),
#  "King's Gambit Accepted, Cunningham Defense, McCormick Defense": np.int64(854),
#  "King's Gambit Accepted, Dodo Variation": np.int64(855),
#  "King's Gambit Accepted, Double Muzio Gambit": np.int64(856),
#  "King's Gambit Accepted, Double Muzio Gambit, Bello Gambit": np.int64(857),
#  "King's Gambit Accepted, Fischer Defense": np.int64(858),
#  "King's Gambit Accepted, Fischer Defense, Spanish Variation": np.int64(859),
#  "King's Gambit Accepted, Gaga Gambit": np.int64(860),
#  "King's Gambit Accepted, Ghulam-Kassim Gambit": np.int64(861),
#  "King's Gambit Accepted, Gianutio Countergambit": np.int64(862),
#  "King's Gambit Accepted, Greco Gambit": np.int64(863),
#  "King's Gambit Accepted, Hanstein Gambit": np.int64(864),
#  "King's Gambit Accepted, Kieseritzky Gambit, Anderssen Defense": np.int64(865),
#  "King's Gambit Accepted, Kieseritzky Gambit, Berlin Defense": np.int64(866),
#  "King's Gambit Accepted, Kieseritzky Gambit, Brentano Defense": np.int64(867),
#  "King's Gambit Accepted, Kieseritzky Gambit, Cotter Gambit": np.int64(868),
#  "King's Gambit Accepted, Kieseritzky Gambit, Kolisch Defense": np.int64(869),
#  "King's Gambit Accepted, Kieseritzky Gambit, Long Whip": np.int64(870),
#  "King's Gambit Accepted, Kieseritzky Gambit, Paulsen Defense": np.int64(871),
#  "King's Gambit Accepted, Kieseritzky Gambit, Rosenthal Defense": np.int64(872),
#  "King's Gambit Accepted, King's Knight Gambit": np.int64(873),
#  "King's Gambit Accepted, Lolli Gambit": np.int64(874),
#  "King's Gambit Accepted, MacLeod Defense": np.int64(875),
#  "King's Gambit Accepted, Mason-Keres Gambit": np.int64(876),
#  "King's Gambit Accepted, Mayet Gambit": np.int64(877),
#  "King's Gambit Accepted, McDonnell Gambit": np.int64(878),
#  "King's Gambit Accepted, Modern Defense": np.int64(879),
#  "King's Gambit Accepted, Muzio Gambit Accepted, From's Defense": np.int64(880),
#  "King's Gambit Accepted, Muzio Gambit, Sarratt Defense": np.int64(881),
#  "King's Gambit Accepted, Muzio Gambit, Wild Muzio Gambit": np.int64(882),
#  "King's Gambit Accepted, Orsini Gambit": np.int64(883),
#  "King's Gambit Accepted, Philidor Gambit": np.int64(884),
#  "King's Gambit Accepted, Polerio Gambit": np.int64(885),
#  "King's Gambit Accepted, Quade Gambit": np.int64(886),
#  "King's Gambit Accepted, Rosentreter Gambit": np.int64(887),
#  "King's Gambit Accepted, Rosentreter Gambit, Bird Gambit": np.int64(888),
#  "King's Gambit Accepted, Rosentreter-Testa Gambit": np.int64(889),
#  "King's Gambit Accepted, Salvio Gambit": np.int64(890),
#  "King's Gambit Accepted, Schallopp Defense": np.int64(891),
#  "King's Gambit Accepted, Stamma Gambit": np.int64(892),
#  "King's Gambit Accepted, Tartakower Gambit": np.int64(893),
#  "King's Gambit Accepted, Traditional Variation": np.int64(894),
#  "King's Gambit Accepted: Allgaier, Schlechter Defense": np.int64(895),
#  "King's Gambit Accepted: Bishop's Gambit, Anderssen Variation": np.int64(896),
#  "King's Gambit Accepted: Bishop's Gambit, Bledow Variation": np.int64(897),
#  "King's Gambit Accepted: Bishop's Gambit, Paulsen Attack": np.int64(898),
#  "King's Gambit Accepted: Bishop's Gambit, Steinitz Defense": np.int64(899),
#  "King's Gambit Accepted: Cunningham, Bertin Gambit": np.int64(900),
#  "King's Gambit Accepted: Ghulam-Kassim Gambit #2": np.int64(901),
#  "King's Gambit Accepted: King Knight's Gambit": np.int64(902),
#  "King's Gambit Accepted: Modern Defense #2": np.int64(903),
#  "King's Gambit Accepted: Muzio Gambit, Kling and Horwitz Counterattack": np.int64(904),
#  "King's Gambit Accepted: Soerensen Gambit": np.int64(905),
#  "King's Gambit Declined, Classical Variation": np.int64(906),
#  "King's Gambit Declined, Classical Variation #2": np.int64(907),
#  "King's Gambit Declined, Keene Defense": np.int64(908),
#  "King's Gambit Declined, Mafia Defense": np.int64(909),
#  "King's Gambit Declined, Miles Defense": np.int64(910),
#  "King's Gambit Declined, Norwalde Variation": np.int64(911),
#  "King's Gambit Declined, Norwalde Variation, Schubert Variation": np.int64(912),
#  "King's Gambit Declined, Petrov's Defense": np.int64(913),
#  "King's Gambit Declined, Queen's Knight Defense": np.int64(914),
#  "King's Gambit Declined, Soller-Zilbermints Gambit": np.int64(915),
#  "King's Gambit Declined: Classical, Soldatenkov Variation": np.int64(916),
#  "King's Gambit Declined: Falkbeer Countergambit": np.int64(917),
#  "King's Gambit Declined: Falkbeer, Charousek Gambit": np.int64(918),
#  "King's Gambit Declined: Falkbeer, Milner-Barry Variation": np.int64(919),
#  "King's Gambit Declined: Falkbeer, Rubinstein Variation": np.int64(920),
#  "King's Gambit Declined: Keene's Defense": np.int64(921),
#  "King's Gambit Declined: Keene's Defense #2": np.int64(922),
#  "King's Gambit, Falkbeer Countergambit Accepted": np.int64(923),
#  "King's Gambit, Falkbeer Countergambit, Anderssen Attack": np.int64(924),
#  "King's Gambit, Falkbeer Countergambit, Blackburne Attack": np.int64(925),
#  "King's Gambit, Falkbeer Countergambit, Charousek Gambit": np.int64(926),
#  "King's Gambit, Falkbeer Countergambit, Charousek Gambit Accepted": np.int64(927),
#  "King's Gambit, Falkbeer Countergambit, Charousek Gambit, Morphy Defense": np.int64(928),
#  "King's Gambit, Falkbeer Countergambit, Charousek Gambit, Old Line": np.int64(929),
#  "King's Gambit, Falkbeer Countergambit, Hinrichsen Gambit": np.int64(930),
#  "King's Gambit, Falkbeer Countergambit, Miles Gambit": np.int64(931),
#  "King's Gambit, Falkbeer Countergambit, Modern Transfer": np.int64(932),
#  "King's Gambit, Falkbeer Countergambit, Nimzowitsch-Marshall Countergambit": np.int64(933),
#  "King's Gambit, Falkbeer Countergambit, Staunton Line": np.int64(934),
#  "King's Gambit: Panteldakis Countergambit": np.int64(935),
#  "King's Gambit: Panteldakis Countergambit, Greco Variation": np.int64(936),
#  "King's Gambit: Panteldakis Countergambit, Schiller's Defense": np.int64(937),
#  "King's Gambit: Zilbermints Double Countergambit": np.int64(938),
#  "King's Indian Attack": np.int64(939),
#  "King's Indian Attack: Double Fianchetto": np.int64(940),
#  "King's Indian Attack: French Variation": np.int64(941),
#  "King's Indian Attack: Keres Variation": np.int64(942),
#  "King's Indian Attack: Keres Variation #2": np.int64(943),
#  "King's Indian Attack: Omega-Delta Gambit": np.int64(944),
#  "King's Indian Attack: Pachman System": np.int64(945),
#  "King's Indian Attack: Sicilian Variation": np.int64(946),
#  "King's Indian Attack: Sicilian Variation #2": np.int64(947),
#  "King's Indian Attack: Spassky Variation": np.int64(948),
#  "King's Indian Attack: Symmetrical Defense": np.int64(949),
#  "King's Indian Attack: Wahls Defense": np.int64(950),
#  "King's Indian Attack: Yugoslav Variation": np.int64(951),
#  "King's Indian Defense": np.int64(952),
#  "King's Indian Defense: 3.Nc3": np.int64(953),
#  "King's Indian Defense: Accelerated Averbakh Variation": np.int64(954),
#  "King's Indian Defense: Averbakh Variation": np.int64(955),
#  "King's Indian Defense: Averbakh Variation, Benoni Defense, Advance Variation": np.int64(956),
#  "King's Indian Defense: Averbakh Variation, Flexible Defense": np.int64(957),
#  "King's Indian Defense: Averbakh Variation, Geller Defense": np.int64(958),
#  "King's Indian Defense: Averbakh Variation, Nc6 Defense": np.int64(959),
#  "King's Indian Defense: Exchange Variation": np.int64(960),
#  "King's Indian Defense: Fianchetto Variation, Classical Fianchetto": np.int64(961),
#  "King's Indian Defense: Fianchetto Variation, Debrecen Defense": np.int64(962),
#  "King's Indian Defense: Fianchetto Variation, Delayed Fianchetto": np.int64(963),
#  "King's Indian Defense: Fianchetto Variation, Hungarian Variation": np.int64(964),
#  "King's Indian Defense: Fianchetto Variation, Immediate Fianchetto": np.int64(965),
#  "King's Indian Defense: Fianchetto Variation, Kavalek Defense": np.int64(966),
#  "King's Indian Defense: Fianchetto Variation, Lesser Simagin (Spassky)": np.int64(967),
#  "King's Indian Defense: Fianchetto Variation, Long Variation": np.int64(968),
#  "King's Indian Defense: Fianchetto Variation, Panno Variation": np.int64(969),
#  "King's Indian Defense: Fianchetto Variation, Simagin Variation": np.int64(970),
#  "King's Indian Defense: Fianchetto Variation, Uhlmann-Szabo System": np.int64(971),
#  "King's Indian Defense: Fianchetto Variation, Yugoslav System, without Nc3": np.int64(972),
#  "King's Indian Defense: Fianchetto Variation, Yugoslav Variation": np.int64(973),
#  "King's Indian Defense: Fianchetto Variation, Yugoslav Variation, Advance Line": np.int64(974),
#  "King's Indian Defense: Fianchetto Variation, Yugoslav Variation, Rare Line": np.int64(975),
#  "King's Indian Defense: Four Pawns Attack": np.int64(976),
#  "King's Indian Defense: Four Pawns Attack, Dynamic Attack": np.int64(977),
#  "King's Indian Defense: Four Pawns Attack, Exchange Variation": np.int64(978),
#  "King's Indian Defense: Four Pawns Attack, Normal Attack": np.int64(979),
#  "King's Indian Defense: Kazakh Variation": np.int64(980),
#  "King's Indian Defense: Kramer Variation": np.int64(981),
#  "King's Indian Defense: Larsen Variation": np.int64(982),
#  "King's Indian Defense: Makogonov Variation": np.int64(983),
#  "King's Indian Defense: Normal Variation": np.int64(984),
#  "King's Indian Defense: Normal Variation, Deferred Fianchetto": np.int64(985),
#  "King's Indian Defense: Normal Variation, King's Knight Variation": np.int64(986),
#  "King's Indian Defense: Normal Variation, Rare Defenses": np.int64(987),
#  "King's Indian Defense: Normal Variation, Standard Development": np.int64(988),
#  "King's Indian Defense: Orthodox Variation": np.int64(989),
#  "King's Indian Defense: Orthodox Variation, Aronin-Taimanov Defense": np.int64(990),
#  "King's Indian Defense: Orthodox Variation, Bayonet Attack": np.int64(991),
#  "King's Indian Defense: Orthodox Variation, Bayonet Attack, Sokolov's Line": np.int64(992),
#  "King's Indian Defense: Orthodox Variation, Classical System": np.int64(993),
#  "King's Indian Defense: Orthodox Variation, Classical System, Neo-Classical Line": np.int64(994),
#  "King's Indian Defense: Orthodox Variation, Classical System, Traditional Line": np.int64(995),
#  "King's Indian Defense: Orthodox Variation, Glek Defense": np.int64(996),
#  "King's Indian Defense: Orthodox Variation, Gligoric-Taimanov System": np.int64(997),
#  "King's Indian Defense: Orthodox Variation, Positional Defense": np.int64(998),
#  "King's Indian Defense: Orthodox Variation, Positional Defense, Closed Line": np.int64(999),
#  ...}

# %%
X = encoded[[ 'WhiteElo', 'BlackElo', 'Opening' ]]
y = encoded.drop([ 'WhiteElo', 'BlackElo', 'Opening' ], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
rf_Model = RandomForestClassifier(n_jobs=12)

# %%
rf_Model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=12)

# %%
# # load
# rf_Model = joblib.load("data/serious_games.joblib")

# %%
print(rf_Model.score(X_train, y_train))
print(rf_Model.score(X_test, y_test))
# Out:
# 0.9979754689944391
# 0.5483256909679862

# %%
white_elo = 1500
black_elo = 1600
opening_encoded = 0


input_data = [[white_elo, black_elo, opening_encoded]]

# Predict probabilities for the input
probabilities = rf_Model.predict_proba(input_data)

# Convert to percentages
percentages = [ prob[0][1] * 100 for prob in probabilities ]

# Assuming you have three possible results: 0 (black win), 1 (white win), 2 (draw)
results = [ 'Black Wins', 'White Wins', 'Draw' ]

# Print the result with percentages
for result, percentage in zip(results, percentages):
    print(f"{result}: {percentage:.2f}%")
# Out:
# Black Wins: 49.00%
# White Wins: 41.00%
# Draw: 10.00%
# c:\Users\TVM0957\miniconda3\envs\py-chess\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
rf_Model.predict([[1825, 2325, 113]])
# Out:
# c:\Users\TVM0957\miniconda3\envs\py-chess\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([[ True, False, False]])

# %%
rf_Model.predict([[2000, 2000, 0]])
# Out:
# c:\Users\TVM0957\miniconda3\envs\py-chess\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([[ True, False, False]])

# %%
# # save
# joblib.dump(rf_Model, "data/serious_games.joblib")
